# %% [markdown]
# ## Validate protein mutations with endstate corrections!!!

# %% [markdown]
# this should tell us if we are at all capable of closing cycles...

# %%
#!/usr/bin/env python
# coding: utf-8

# # Here, I document an attempt to validate a small set of protein mutations in vacuum and solvent with the following checks...

# 1. generate alanine dipeptide --> valine dipeptide in vac/solvent and conduct a forward _and_ reverse parallel tempering FEP calculation; the check passes if the forward free energy is equal to the reverse free energy within an error tolerance
# 2. generate alanine dipeptide --> valine dipeptide --> isoleucine dipeptide --> glycine dipeptide and attempt to close the thermodynamic cycle within an error tolerance

# In[ ]:


from __future__ import absolute_import

import networkx as nx
from perses.dispersed import feptasks
from perses.utils.openeye import *
from perses.utils.data import load_smi
from perses.annihilation.relative import HybridTopologyFactory
from perses.annihilation.lambda_protocol import RelativeAlchemicalState, LambdaProtocol
from perses.rjmc.topology_proposal import TopologyProposal, TwoMoleculeSetProposalEngine, SystemGenerator,SmallMoleculeSetProposalEngine, PointMutationEngine
from perses.rjmc.geometry import FFAllAngleGeometryEngine
import simtk.openmm.app as app
import sys

from openmmtools.states import ThermodynamicState, CompoundThermodynamicState, SamplerState

import pymbar
import simtk.openmm as openmm
import simtk.openmm.app as app
import simtk.unit as unit
import numpy as np
from openmoltools import forcefield_generators
import copy
import pickle
import mdtraj as md
from io import StringIO
from openmmtools.constants import kB
import logging
import os
import dask.distributed as distributed
import parmed as pm
from collections import namedtuple
from typing import List, Tuple, Union, NamedTuple
from collections import namedtuple
import random
#beta = 1.0/(kB*temperature)
import itertools
import os
from openeye import oechem
from perses.utils.smallmolecules import render_atom_mapping
from perses.tests.utils import validate_endstate_energies

ENERGY_THRESHOLD = 1e-6
temperature = 300 * unit.kelvin
kT = kB * temperature
beta = 1.0/kT
from perses.tests.utils import validate_endstate_energies


# In[ ]:


from perses.samplers.multistate import HybridSAMSSampler, HybridRepexSampler
from openmmtools.multistate import MultiStateReporter, MultiStateSamplerAnalyzer
from openmmtools import mcmc, utils
from perses.annihilation.lambda_protocol import LambdaProtocol


# In[ ]:


def generate_atp(phase = 'vacuum'):
    """
    modify the AlanineDipeptideVacuum test system to be parametrized with amber14ffsb in vac or solvent (tip3p)
    """
    import openmmtools.testsystems as ts
    atp = ts.AlanineDipeptideVacuum(constraints = app.HBonds, hydrogenMass = 4 * unit.amus)

    forcefield_files = ['gaff.xml', 'amber14/protein.ff14SB.xml', 'amber14/tip3p.xml']
    
    if phase == 'vacuum':
        barostat = None
        system_generator = SystemGenerator(forcefield_files,
                                       barostat = barostat,
                                       forcefield_kwargs = {'removeCMMotion': False, 
                                                            'ewaldErrorTolerance': 1e-4, 
                                                            'nonbondedMethod': app.NoCutoff,
                                                            'constraints' : app.HBonds, 
                                                            'hydrogenMass' : 4 * unit.amus})
        atp.system = system_generator.build_system(atp.topology) #update the parametrization scheme to amberff14sb
        
    elif phase == 'solvent':
        barostat = openmm.MonteCarloBarostat(1.0 * unit.atmosphere, 300 * unit.kelvin, 50)
        system_generator = SystemGenerator(forcefield_files,
                                   barostat = barostat,
                                   forcefield_kwargs = {'removeCMMotion': False, 
                                                        'ewaldErrorTolerance': 1e-4, 
                                                        'nonbondedMethod': app.PME,
                                                        'constraints' : app.HBonds, 
                                                        'hydrogenMass' : 4 * unit.amus})
    
    if phase == 'solvent':
        modeller = app.Modeller(atp.topology, atp.positions)
        modeller.addSolvent(system_generator._forcefield, model='tip3p', padding=9*unit.angstroms, ionicStrength=0.15*unit.molar)
        solvated_topology = modeller.getTopology()
        solvated_positions = modeller.getPositions()

        # canonicalize the solvated positions: turn tuples into np.array
        atp.positions = unit.quantity.Quantity(value = np.array([list(atom_pos) for atom_pos in solvated_positions.value_in_unit_system(unit.md_unit_system)]), unit = unit.nanometers)
        atp.topology = solvated_topology

        atp.system = system_generator.build_system(atp.topology)
    
    
    return atp, system_generator


# In[ ]:


def generate_top_pos_sys(topology, new_res, system, positions, system_generator):
    """generate point mutation engine, geometry_engine, and conduct topology proposal, geometry propsal, and hybrid factory generation"""
    #create the point mutation engine
    print(f"generating point mutation engine")
    point_mutation_engine = PointMutationEngine(wildtype_topology = topology,
                                                system_generator = system_generator,
                                                chain_id = '1', #denote the chain id allowed to mutate (it's always a string variable)
                                                max_point_mutants = 1,
                                                residues_allowed_to_mutate = ['2'], #the residue ids allowed to mutate
                                                allowed_mutations = [('2', new_res)], #the residue ids allowed to mutate with the three-letter code allowed to change
                                                aggregate = True) #always allow aggregation

    #create a geometry engine
    print(f"generating geometry engine")
    geometry_engine = FFAllAngleGeometryEngine(metadata=None, 
                                           use_sterics=False, 
                                           n_bond_divisions=100, 
                                           n_angle_divisions=180, 
                                           n_torsion_divisions=360, 
                                           verbose=True, 
                                           storage=None, 
                                           bond_softening_constant=1.0, 
                                           angle_softening_constant=1.0, 
                                           neglect_angles = False, 
                                           use_14_nonbondeds = True)

    #create a top proposal
    print(f"making topology proposal")
    topology_proposal, local_map_stereo_sidechain, new_oemol_sidechain, old_oemol_sidechain = point_mutation_engine.propose(current_system = system,
                                  current_topology = topology)

    #make a geometry proposal forward
    print(f"making geometry proposal from {list(topology.residues())[1].name} to {new_res}")
    forward_new_positions, logp_proposal = geometry_engine.propose(topology_proposal, positions, beta)
    logp_reverse = geometry_engine.logp_reverse(topology_proposal, forward_new_positions, positions, beta)


    #create a hybrid topology factory
    f"making forward hybridtopologyfactory"
    forward_htf = HybridTopologyFactory(topology_proposal = topology_proposal,
                 current_positions =  positions,
                 new_positions = forward_new_positions,
                 use_dispersion_correction = False,
                 functions=None,
                 softcore_alpha = None,
                 bond_softening_constant=1.0,
                 angle_softening_constant=1.0,
                 soften_only_new = False,
                 neglected_new_angle_terms = [],
                 neglected_old_angle_terms = [],
                 softcore_LJ_v2 = True,
                 softcore_electrostatics = True,
                 softcore_LJ_v2_alpha = 0.85,
                 softcore_electrostatics_alpha = 0.3,
                 softcore_sigma_Q = 1.0,
                 interpolate_old_and_new_14s = False,
                 omitted_terms = None)
    
    if not topology_proposal.unique_new_atoms:
        assert geometry_engine.forward_final_context_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.forward_final_context_reduced_potential})"
        assert geometry_engine.forward_atoms_with_positions_reduced_potential == None, f"There are no unique new atoms but the geometry_engine's forward atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.forward_atoms_with_positions_reduced_potential})"
        vacuum_added_valence_energy = 0.0
    else:
        added_valence_energy = geometry_engine.forward_final_context_reduced_potential - geometry_engine.forward_atoms_with_positions_reduced_potential

    if not topology_proposal.unique_old_atoms:
        assert geometry_engine.reverse_final_context_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's final context reduced potential is not None (i.e. {self._geometry_engine.reverse_final_context_reduced_potential})"
        assert geometry_engine.reverse_atoms_with_positions_reduced_potential == None, f"There are no unique old atoms but the geometry_engine's atoms-with-positions-reduced-potential in not None (i.e. { self._geometry_engine.reverse_atoms_with_positions_reduced_potential})"
        subtracted_valence_energy = 0.0
    else:
        subtracted_valence_energy = geometry_engine.reverse_final_context_reduced_potential - geometry_engine.reverse_atoms_with_positions_reduced_potential

#     self._vacuum_forward_neglected_angles = self._geometry_engine.forward_neglected_angle_terms
#     self._vacuum_reverse_neglected_angles = self._geometry_engine.reverse_neglected_angle_terms
#     self._vacuum_geometry_engine = copy.deepcopy(self._geometry_engine)
    
#     zero_state_error, one_state_error = validate_endstate_energies(forward_htf._topology_proposal, forward_htf, added_valence_energy, subtracted_valence_energy, beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD)
#     print(f"zero state error : {zero_state_error}")
#     print(f"one state error : {one_state_error}")
    
    return topology_proposal, forward_new_positions, forward_htf, local_map_stereo_sidechain, old_oemol_sidechain, new_oemol_sidechain, added_valence_energy, subtracted_valence_energy


# In[ ]:


# def create_hss(reporter_name, hybrid_factory, selection_string ='all', checkpoint_interval = 1, n_states = 13):
#     lambda_protocol = LambdaProtocol(functions='default')
#     reporter = MultiStateReporter(reporter_name, analysis_particle_indices = hybrid_factory.hybrid_topology.select(selection_string), checkpoint_interval = checkpoint_interval)
#     hss = HybridRepexSampler(mcmc_moves=mcmc.LangevinSplittingDynamicsMove(timestep= 4.0 * unit.femtoseconds,
#                                                                                  collision_rate=5.0 / unit.picosecond,
#                                                                                  n_steps=250,
#                                                                                  reassign_velocities=False,
#                                                                                  n_restart_attempts=20,
#                                                                                  splitting="V R R R O R R R V",
#                                                                                  constraint_tolerance=1e-06),
#                                                                                  hybrid_factory=hybrid_factory, online_analysis_interval=10)
#     hss.setup(n_states=n_states, temperature=300*unit.kelvin,storage_file=reporter,lambda_protocol=lambda_protocol,endstates=False)
#     return hss, reporter


# let's make a function to generate an n node graph and run a computation on it...

    


# In[ ]:


def generate_fully_connected_perturbation_graph(dipeptides = ['ALA', 'PHE'], phase = 'vacuum'):
    # generate a fully connected solvation energy graph for the dipeptides specified...
    graph = nx.DiGraph()
    for dipeptide in dipeptides:
        graph.add_node(dipeptide)
    
    #now for edges...
    for i in graph.nodes():
        for j in graph.nodes():
            if i != j:
                graph.add_edge(i, j)
    
    
    #start with ala
    atp, system_generator = generate_atp(phase = phase)
    
    #graph.nodes['ALA']['vac_sys_pos_top'] = (vac_atp.system, vac_atp.positions, vac_atp.topology)
    graph.nodes['ALA']['sys_pos_top'] = (atp.system, atp.positions, atp.topology)
    
    #turn ala into all of the other dipeptides
    for dipeptide in [pep for pep in dipeptides if pep != 'ALA']:
        for _phase, testcase, sys_gen in zip([phase], [atp], [system_generator]):
            top_prop, new_positions, htf, local_map_stereo_sidechain, old_oemol, new_oemol, added_e, subtracted_e =  generate_top_pos_sys(testcase.topology, dipeptide, testcase.system, testcase.positions, sys_gen)
            new_sys, new_pos, new_top = htf._new_system, htf._new_positions, top_prop._new_topology
            graph.nodes[dipeptide][f"{_phase}_sys_pos_top"] = (new_sys, new_pos, new_top)
            graph.edges[('ALA', dipeptide)][f'{_phase}_htf'] = htf
            graph.edges[('ALA', dipeptide)][f"map_oldmol_newmol"] = (local_map_stereo_sidechain, old_oemol, new_oemol)
            graph.edges[('ALA', dipeptide)][f"added_subtracted"] = (added_e, subtracted_e)

        
        
    #now we can turn all of the other states in to each other!!!
    for edge_start, edge_end in list(graph.edges()):
        if edge_start == 'ALA': #we already did ALA
            continue
        
        for _phase, sys_gen in zip([phase], [system_generator]):
            sys, pos, top = graph.nodes[edge_start][f"{_phase}_sys_pos_top"]
            top_prop, new_positions, htf, local_map_stereo_sidechain, old_oemol, new_oemol, added_e, subtracted_e = generate_top_pos_sys(top, edge_end, sys, pos, sys_gen)
            new_sys, new_pos, new_top = htf._new_system, htf._new_positions, top_prop._new_topology
            graph.nodes[edge_end][f"{_phase}_sys_pos_top"] = (new_sys, new_pos, new_top)
            graph.edges[(edge_start, edge_end)][f"{_phase}_htf"] = htf
            graph.edges[(edge_start, edge_end)][f"map_oldmol_newmol"] = (local_map_stereo_sidechain, old_oemol, new_oemol)
            graph.edges[(edge_start, edge_end)][f"added_subtracted"] = (added_e, subtracted_e)
            
    print(f"graph_edges: {graph.edges()}")
    
    return graph
        


# In[ ]:


#os.system(f"rm *.nc")
# Out:
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.1']
#     $0.2 = getattr(value=$0.1, attr=zeros)   ['$0.1', '$0.2']
#     $const0.3 = const(int, 3)                ['$const0.3']
#     $0.4 = call $0.2($const0.3, func=$0.2, args=[Var($const0.3, coordinate_numba.py:6)], kws=(), vararg=None) ['$0.2', '$0.4', '$const0.3']
#     c = $0.4                                 ['$0.4', 'c']
#     $const0.6 = const(int, 1)                ['$const0.6']
#     $0.7 = getitem(value=a, index=$const0.6) ['$0.7', '$const0.6', 'a']
#     $const0.9 = const(int, 2)                ['$const0.9']
#     $0.10 = getitem(value=b, index=$const0.9) ['$0.10', '$const0.9', 'b']
#     $0.11 = $0.7 * $0.10                     ['$0.10', '$0.11', '$0.7']
#     $const0.13 = const(int, 2)               ['$const0.13']
#     $0.14 = getitem(value=a, index=$const0.13) ['$0.14', '$const0.13', 'a']
#     $const0.16 = const(int, 1)               ['$const0.16']
#     $0.17 = getitem(value=b, index=$const0.16) ['$0.17', '$const0.16', 'b']
#     $0.18 = $0.14 * $0.17                    ['$0.14', '$0.17', '$0.18']
#     $0.19 = $0.11 - $0.18                    ['$0.11', '$0.18', '$0.19']
#     $const0.21 = const(int, 0)               ['$const0.21']
#     c[$const0.21] = $0.19                    ['$0.19', '$const0.21', 'c']
#     $const0.23 = const(int, 2)               ['$const0.23']
#     $0.24 = getitem(value=a, index=$const0.23) ['$0.24', '$const0.23', 'a']
#     $const0.26 = const(int, 0)               ['$const0.26']
#     $0.27 = getitem(value=b, index=$const0.26) ['$0.27', '$const0.26', 'b']
#     $0.28 = $0.24 * $0.27                    ['$0.24', '$0.27', '$0.28']
#     $const0.30 = const(int, 0)               ['$const0.30']
#     $0.31 = getitem(value=a, index=$const0.30) ['$0.31', '$const0.30', 'a']
#     $const0.33 = const(int, 2)               ['$const0.33']
#     $0.34 = getitem(value=b, index=$const0.33) ['$0.34', '$const0.33', 'b']
#     $0.35 = $0.31 * $0.34                    ['$0.31', '$0.34', '$0.35']
#     $0.36 = $0.28 - $0.35                    ['$0.28', '$0.35', '$0.36']
#     $const0.38 = const(int, 1)               ['$const0.38']
#     c[$const0.38] = $0.36                    ['$0.36', '$const0.38', 'c']
#     $const0.40 = const(int, 0)               ['$const0.40']
#     $0.41 = getitem(value=a, index=$const0.40) ['$0.41', '$const0.40', 'a']
#     $const0.43 = const(int, 1)               ['$const0.43']
#     $0.44 = getitem(value=b, index=$const0.43) ['$0.44', '$const0.43', 'b']
#     $0.45 = $0.41 * $0.44                    ['$0.41', '$0.44', '$0.45']
#     $const0.47 = const(int, 1)               ['$const0.47']
#     $0.48 = getitem(value=a, index=$const0.47) ['$0.48', '$const0.47', 'a']
#     $const0.50 = const(int, 0)               ['$const0.50']
#     $0.51 = getitem(value=b, index=$const0.50) ['$0.51', '$const0.50', 'b']
#     $0.52 = $0.48 * $0.51                    ['$0.48', '$0.51', '$0.52']
#     $0.53 = $0.45 - $0.52                    ['$0.45', '$0.52', '$0.53']
#     $const0.55 = const(int, 2)               ['$const0.55']
#     c[$const0.55] = $0.53                    ['$0.53', '$const0.55', 'c']
#     $0.57 = cast(value=c)                    ['$0.57', 'c']
#     return $0.57                             ['$0.57']
#
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     $0.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.1']
#     $0.2 = getattr(value=$0.1, attr=dot)     ['$0.1', '$0.2']
#     $0.5 = call $0.2(a, a, func=$0.2, args=[Var(a, coordinate_numba.py:14), Var(a, coordinate_numba.py:14)], kws=(), vararg=None) ['$0.2', '$0.5', 'a', 'a']
#     n_2 = $0.5                               ['$0.5', 'n_2']
#     $0.6 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.6']
#     $0.7 = getattr(value=$0.6, attr=sqrt)    ['$0.6', '$0.7']
#     $0.9 = call $0.7(n_2, func=$0.7, args=[Var(n_2, coordinate_numba.py:14)], kws=(), vararg=None) ['$0.7', '$0.9', 'n_2']
#     $0.10 = cast(value=$0.9)                 ['$0.10', '$0.9']
#     return $0.10                             ['$0.10']
#
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/perses-0.4.0-py3.6.egg/perses/rjmc/coordinate_numba.py:14: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   n_2 = np.dot(a, a)
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.2 = getattr(value=a, attr=shape)      ['$0.2', 'a']
#     $0.4 = exhaust_iter(value=$0.2, count=1) ['$0.2', '$0.4']
#     $0.3 = static_getitem(value=$0.4, index=0, index_var=None) ['$0.3', '$0.4']
#     m = $0.3                                 ['$0.3', 'm']
#     $0.6 = getattr(value=b, attr=shape)      ['$0.6', 'b']
#     $0.8 = exhaust_iter(value=$0.6, count=1) ['$0.6', '$0.8']
#     $0.7 = static_getitem(value=$0.8, index=0, index_var=None) ['$0.7', '$0.8']
#     n = $0.7                                 ['$0.7', 'n']
#     $0.11 = m != n                           ['$0.11', 'm', 'n']
#     branch $0.11, 26, 34                     ['$0.11']
# label 26:
#     $26.1 = global(ValueError: <class 'ValueError'>) ['$26.1']
#     $const26.2 = const(str, incompatible array sizes for np.dot(a, b) (vector * vector)) ['$const26.2']
#     $26.3 = call $26.1($const26.2, func=$26.1, args=[Var($const26.2, linalg.py:510)], kws=(), vararg=None) ['$26.1', '$26.3', '$const26.2']
#     raise $26.3                              ['$26.3']
# label 34:
#     $const34.1 = const(NoneType, None)       ['$const34.1']
#     $34.2 = cast(value=$const34.1)           ['$34.2', '$const34.1']
#     return $34.2                             ['$34.2']
#
# DEBUG:numba.interpreter:label 0:
#     n = arg(0, name=n)                       ['n']
#     $0.2 = freevar(_maxint: 2147483647)      ['$0.2']
#     $0.3 = n > $0.2                          ['$0.2', '$0.3', 'n']
#     branch $0.3, 10, 18                      ['$0.3']
# label 10:
#     $10.1 = global(OverflowError: <class 'OverflowError'>) ['$10.1']
#     $const10.2 = const(str, array size too large to fit in C int) ['$const10.2']
#     $10.3 = call $10.1($const10.2, func=$10.1, args=[Var($const10.2, linalg.py:314)], kws=(), vararg=None) ['$10.1', '$10.3', '$const10.2']
#     raise $10.3                              ['$10.3']
# label 18:
#     $const18.1 = const(NoneType, None)       ['$const18.1']
#     $18.2 = cast(value=$const18.1)           ['$18.2', '$const18.1']
#     return $18.2                             ['$18.2']
#
# DEBUG:numba.interpreter:label 0:
#     axis = arg(0, name=axis)                 ['axis']
#     angle = arg(1, name=angle)               ['angle']
#     $0.1 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.1']
#     $0.3 = call $0.1(axis, func=$0.1, args=[Var(axis, coordinate_numba.py:22)], kws=(), vararg=None) ['$0.1', '$0.3', 'axis']
#     axis_norm = $0.3                         ['$0.3', 'axis_norm']
#     jump 10                                  []
# label 10:
#     jump 12                                  []
# label 12:
#     $12.1 = global(range: <class 'range'>)   ['$12.1']
#     $const12.2 = const(int, 3)               ['$const12.2']
#     $12.3 = call $12.1($const12.2, func=$12.1, args=[Var($const12.2, coordinate_numba.py:23)], kws=(), vararg=None) ['$12.1', '$12.3', '$const12.2']
#     $12.4 = getiter(value=$12.3)             ['$12.3', '$12.4']
#     $phi20.1 = $12.4                         ['$12.4', '$phi20.1']
#     jump 20                                  []
# label 20:
#     $20.2 = iternext(value=$phi20.1)         ['$20.2', '$phi20.1']
#     $20.3 = pair_first(value=$20.2)          ['$20.2', '$20.3']
#     $20.4 = pair_second(value=$20.2)         ['$20.2', '$20.4']
#     $phi22.1 = $20.3                         ['$20.3', '$phi22.1']
#     $phi42.1 = $20.3                         ['$20.3', '$phi42.1']
#     $phi42.2 = $phi20.1                      ['$phi20.1', '$phi42.2']
#     branch $20.4, 22, 42                     ['$20.4']
# label 22:
#     k = $phi22.1                             ['$phi22.1', 'k']
#     $22.4 = getitem(value=axis, index=k)     ['$22.4', 'axis', 'k']
#     $22.6 = $22.4 / axis_norm                ['$22.4', '$22.6', 'axis_norm']
#     axis[k] = $22.6                          ['$22.6', 'axis', 'k']
#     jump 20                                  []
# label 42:
#     jump 44                                  []
# label 44:
#     $const44.2 = const(int, 2)               ['$const44.2']
#     $44.3 = axis ** $const44.2               ['$44.3', '$const44.2', 'axis']
#     axis_squared = $44.3                     ['$44.3', 'axis_squared']
#     $44.4 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$44.4']
#     $44.5 = getattr(value=$44.4, attr=cos)   ['$44.4', '$44.5']
#     $44.7 = call $44.5(angle, func=$44.5, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None) ['$44.5', '$44.7', 'angle']
#     cos_angle = $44.7                        ['$44.7', 'cos_angle']
#     $44.8 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$44.8']
#     $44.9 = getattr(value=$44.8, attr=sin)   ['$44.8', '$44.9']
#     $44.11 = call $44.9(angle, func=$44.9, args=[Var(angle, coordinate_numba.py:22)], kws=(), vararg=None) ['$44.11', '$44.9', 'angle']
#     sin_angle = $44.11                       ['$44.11', 'sin_angle']
#     $44.12 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$44.12']
#     $44.13 = getattr(value=$44.12, attr=zeros) ['$44.12', '$44.13']
#     $const_3 = const(int, 3)                 ['$const_3']
#     $const_3.1 = const(int, 3)               ['$const_3.1']
#     $const44.14 = build_tuple(items=[Var($const_3, coordinate_numba.py:29), Var($const_3.1, coordinate_numba.py:29)]) ['$const44.14', '$const_3', '$const_3.1']
#     $44.15 = global(float64: float64)        ['$44.15']
#     $44.17 = call $44.13($const44.14, func=$44.13, args=[Var($const44.14, coordinate_numba.py:29)], kws=[('dtype', Var($44.15, coordinate_numba.py:29))], vararg=None) ['$44.13', '$44.15', '$44.17', '$const44.14']
#     rotation_matrix = $44.17                 ['$44.17', 'rotation_matrix']
#     $const44.20 = const(int, 0)              ['$const44.20']
#     $44.21 = getitem(value=axis_squared, index=$const44.20) ['$44.21', '$const44.20', 'axis_squared']
#     $const44.22 = const(float, 1.0)          ['$const44.22']
#     $44.24 = $const44.22 - cos_angle         ['$44.24', '$const44.22', 'cos_angle']
#     $44.25 = $44.21 * $44.24                 ['$44.21', '$44.24', '$44.25']
#     $44.26 = cos_angle + $44.25              ['$44.25', '$44.26', 'cos_angle']
#     $const_0 = const(int, 0)                 ['$const_0']
#     $const_0.1 = const(int, 0)               ['$const_0.1']
#     $const44.28 = build_tuple(items=[Var($const_0, coordinate_numba.py:31), Var($const_0.1, coordinate_numba.py:31)]) ['$const44.28', '$const_0', '$const_0.1']
#     rotation_matrix[$const44.28] = $44.26    ['$44.26', '$const44.28', 'rotation_matrix']
#     $const44.30 = const(int, 0)              ['$const44.30']
#     $44.31 = getitem(value=axis, index=$const44.30) ['$44.31', '$const44.30', 'axis']
#     $const44.33 = const(int, 1)              ['$const44.33']
#     $44.34 = getitem(value=axis, index=$const44.33) ['$44.34', '$const44.33', 'axis']
#     $44.35 = $44.31 * $44.34                 ['$44.31', '$44.34', '$44.35']
#     $const44.36 = const(float, 1.0)          ['$const44.36']
#     $44.38 = $const44.36 - cos_angle         ['$44.38', '$const44.36', 'cos_angle']
#     $44.39 = $44.35 * $44.38                 ['$44.35', '$44.38', '$44.39']
#     $const44.41 = const(int, 2)              ['$const44.41']
#     $44.42 = getitem(value=axis, index=$const44.41) ['$44.42', '$const44.41', 'axis']
#     $44.44 = $44.42 * sin_angle              ['$44.42', '$44.44', 'sin_angle']
#     $44.45 = $44.39 - $44.44                 ['$44.39', '$44.44', '$44.45']
#     $const_0.2 = const(int, 0)               ['$const_0.2']
#     $const_1 = const(int, 1)                 ['$const_1']
#     $const44.47 = build_tuple(items=[Var($const_0.2, coordinate_numba.py:32), Var($const_1, coordinate_numba.py:32)]) ['$const44.47', '$const_0.2', '$const_1']
#     rotation_matrix[$const44.47] = $44.45    ['$44.45', '$const44.47', 'rotation_matrix']
#     $const44.49 = const(int, 0)              ['$const44.49']
#     $44.50 = getitem(value=axis, index=$const44.49) ['$44.50', '$const44.49', 'axis']
#     $const44.52 = const(int, 2)              ['$const44.52']
#     $44.53 = getitem(value=axis, index=$const44.52) ['$44.53', '$const44.52', 'axis']
#     $44.54 = $44.50 * $44.53                 ['$44.50', '$44.53', '$44.54']
#     $const44.55 = const(float, 1.0)          ['$const44.55']
#     $44.57 = $const44.55 - cos_angle         ['$44.57', '$const44.55', 'cos_angle']
#     $44.58 = $44.54 * $44.57                 ['$44.54', '$44.57', '$44.58']
#     $const44.60 = const(int, 1)              ['$const44.60']
#     $44.61 = getitem(value=axis, index=$const44.60) ['$44.61', '$const44.60', 'axis']
#     $44.63 = $44.61 * sin_angle              ['$44.61', '$44.63', 'sin_angle']
#     $44.64 = $44.58 + $44.63                 ['$44.58', '$44.63', '$44.64']
#     $const_0.3 = const(int, 0)               ['$const_0.3']
#     $const_2 = const(int, 2)                 ['$const_2']
#     $const44.66 = build_tuple(items=[Var($const_0.3, coordinate_numba.py:33), Var($const_2, coordinate_numba.py:33)]) ['$const44.66', '$const_0.3', '$const_2']
#     rotation_matrix[$const44.66] = $44.64    ['$44.64', '$const44.66', 'rotation_matrix']
#     $const44.68 = const(int, 1)              ['$const44.68']
#     $44.69 = getitem(value=axis, index=$const44.68) ['$44.69', '$const44.68', 'axis']
#     $const44.71 = const(int, 0)              ['$const44.71']
#     $44.72 = getitem(value=axis, index=$const44.71) ['$44.72', '$const44.71', 'axis']
#     $44.73 = $44.69 * $44.72                 ['$44.69', '$44.72', '$44.73']
#     $const44.74 = const(float, 1.0)          ['$const44.74']
#     $44.76 = $const44.74 - cos_angle         ['$44.76', '$const44.74', 'cos_angle']
#     $44.77 = $44.73 * $44.76                 ['$44.73', '$44.76', '$44.77']
#     $const44.79 = const(int, 2)              ['$const44.79']
#     $44.80 = getitem(value=axis, index=$const44.79) ['$44.80', '$const44.79', 'axis']
#     $44.82 = $44.80 * sin_angle              ['$44.80', '$44.82', 'sin_angle']
#     $44.83 = $44.77 + $44.82                 ['$44.77', '$44.82', '$44.83']
#     $const_1.1 = const(int, 1)               ['$const_1.1']
#     $const_0.4 = const(int, 0)               ['$const_0.4']
#     $const44.85 = build_tuple(items=[Var($const_1.1, coordinate_numba.py:35), Var($const_0.4, coordinate_numba.py:35)]) ['$const44.85', '$const_0.4', '$const_1.1']
#     rotation_matrix[$const44.85] = $44.83    ['$44.83', '$const44.85', 'rotation_matrix']
#     $const44.88 = const(int, 1)              ['$const44.88']
#     $44.89 = getitem(value=axis_squared, index=$const44.88) ['$44.89', '$const44.88', 'axis_squared']
#     $const44.90 = const(float, 1.0)          ['$const44.90']
#     $44.92 = $const44.90 - cos_angle         ['$44.92', '$const44.90', 'cos_angle']
#     $44.93 = $44.89 * $44.92                 ['$44.89', '$44.92', '$44.93']
#     $44.94 = cos_angle + $44.93              ['$44.93', '$44.94', 'cos_angle']
#     $const_1.2 = const(int, 1)               ['$const_1.2']
#     $const_1.3 = const(int, 1)               ['$const_1.3']
#     $const44.96 = build_tuple(items=[Var($const_1.2, coordinate_numba.py:36), Var($const_1.3, coordinate_numba.py:36)]) ['$const44.96', '$const_1.2', '$const_1.3']
#     rotation_matrix[$const44.96] = $44.94    ['$44.94', '$const44.96', 'rotation_matrix']
#     $const44.98 = const(int, 1)              ['$const44.98']
#     $44.99 = getitem(value=axis, index=$const44.98) ['$44.99', '$const44.98', 'axis']
#     $const44.101 = const(int, 2)             ['$const44.101']
#     $44.102 = getitem(value=axis, index=$const44.101) ['$44.102', '$const44.101', 'axis']
#     $44.103 = $44.99 * $44.102               ['$44.102', '$44.103', '$44.99']
#     $const44.104 = const(float, 1.0)         ['$const44.104']
#     $44.106 = $const44.104 - cos_angle       ['$44.106', '$const44.104', 'cos_angle']
#     $44.107 = $44.103 * $44.106              ['$44.103', '$44.106', '$44.107']
#     $const44.109 = const(int, 0)             ['$const44.109']
#     $44.110 = getitem(value=axis, index=$const44.109) ['$44.110', '$const44.109', 'axis']
#     $44.112 = $44.110 * sin_angle            ['$44.110', '$44.112', 'sin_angle']
#     $44.113 = $44.107 - $44.112              ['$44.107', '$44.112', '$44.113']
#     $const_1.4 = const(int, 1)               ['$const_1.4']
#     $const_2.1 = const(int, 2)               ['$const_2.1']
#     $const44.115 = build_tuple(items=[Var($const_1.4, coordinate_numba.py:37), Var($const_2.1, coordinate_numba.py:37)]) ['$const44.115', '$const_1.4', '$const_2.1']
#     rotation_matrix[$const44.115] = $44.113  ['$44.113', '$const44.115', 'rotation_matrix']
#     $const44.117 = const(int, 2)             ['$const44.117']
#     $44.118 = getitem(value=axis, index=$const44.117) ['$44.118', '$const44.117', 'axis']
#     $const44.120 = const(int, 0)             ['$const44.120']
#     $44.121 = getitem(value=axis, index=$const44.120) ['$44.121', '$const44.120', 'axis']
#     $44.122 = $44.118 * $44.121              ['$44.118', '$44.121', '$44.122']
#     $const44.123 = const(float, 1.0)         ['$const44.123']
#     $44.125 = $const44.123 - cos_angle       ['$44.125', '$const44.123', 'cos_angle']
#     $44.126 = $44.122 * $44.125              ['$44.122', '$44.125', '$44.126']
#     $const44.128 = const(int, 1)             ['$const44.128']
#     $44.129 = getitem(value=axis, index=$const44.128) ['$44.129', '$const44.128', 'axis']
#     $44.131 = $44.129 * sin_angle            ['$44.129', '$44.131', 'sin_angle']
#     $44.132 = $44.126 - $44.131              ['$44.126', '$44.131', '$44.132']
#     $const_2.2 = const(int, 2)               ['$const_2.2']
#     $const_0.5 = const(int, 0)               ['$const_0.5']
#     $const44.134 = build_tuple(items=[Var($const_2.2, coordinate_numba.py:39), Var($const_0.5, coordinate_numba.py:39)]) ['$const44.134', '$const_0.5', '$const_2.2']
#     rotation_matrix[$const44.134] = $44.132  ['$44.132', '$const44.134', 'rotation_matrix']
#     $const44.136 = const(int, 2)             ['$const44.136']
#     $44.137 = getitem(value=axis, index=$const44.136) ['$44.137', '$const44.136', 'axis']
#     $const44.139 = const(int, 1)             ['$const44.139']
#     $44.140 = getitem(value=axis, index=$const44.139) ['$44.140', '$const44.139', 'axis']
#     $44.141 = $44.137 * $44.140              ['$44.137', '$44.140', '$44.141']
#     $const44.142 = const(float, 1.0)         ['$const44.142']
#     $44.144 = $const44.142 - cos_angle       ['$44.144', '$const44.142', 'cos_angle']
#     $44.145 = $44.141 * $44.144              ['$44.141', '$44.144', '$44.145']
#     $const44.147 = const(int, 0)             ['$const44.147']
#     $44.148 = getitem(value=axis, index=$const44.147) ['$44.148', '$const44.147', 'axis']
#     $44.150 = $44.148 * sin_angle            ['$44.148', '$44.150', 'sin_angle']
#     $44.151 = $44.145 + $44.150              ['$44.145', '$44.150', '$44.151']
#     $const_2.3 = const(int, 2)               ['$const_2.3']
#     $const_1.5 = const(int, 1)               ['$const_1.5']
#     $const44.153 = build_tuple(items=[Var($const_2.3, coordinate_numba.py:40), Var($const_1.5, coordinate_numba.py:40)]) ['$const44.153', '$const_1.5', '$const_2.3']
#     rotation_matrix[$const44.153] = $44.151  ['$44.151', '$const44.153', 'rotation_matrix']
#     $const44.156 = const(int, 2)             ['$const44.156']
#     $44.157 = getitem(value=axis_squared, index=$const44.156) ['$44.157', '$const44.156', 'axis_squared']
#     $const44.158 = const(float, 1.0)         ['$const44.158']
#     $44.160 = $const44.158 - cos_angle       ['$44.160', '$const44.158', 'cos_angle']
#     $44.161 = $44.157 * $44.160              ['$44.157', '$44.160', '$44.161']
#     $44.162 = cos_angle + $44.161            ['$44.161', '$44.162', 'cos_angle']
#     $const_2.4 = const(int, 2)               ['$const_2.4']
#     $const_2.5 = const(int, 2)               ['$const_2.5']
#     $const44.164 = build_tuple(items=[Var($const_2.4, coordinate_numba.py:41), Var($const_2.5, coordinate_numba.py:41)]) ['$const44.164', '$const_2.4', '$const_2.5']
#     rotation_matrix[$const44.164] = $44.162  ['$44.162', '$const44.164', 'rotation_matrix']
#     $44.166 = cast(value=rotation_matrix)    ['$44.166', 'rotation_matrix']
#     return $44.166                           ['$44.166']
#
# DEBUG:numba.interpreter:label 0:
#     axis = arg(0, name=axis)                 ['axis']
#     $const0.2 = const(int, 2)                ['$const0.2']
#     $0.3 = axis ** $const0.2                 ['$0.3', '$const0.2', 'axis']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.1 = freevar(tp: float64)              ['$0.1']
#     $const0.2 = const(int, 1)                ['$const0.2']
#     $0.3 = call $0.1($const0.2, func=$0.1, args=[Var($const0.2, numbers.py:225)], kws=(), vararg=None) ['$0.1', '$0.3', '$const0.2']
#     r = $0.3                                 ['$0.3', 'r']
#     $0.4 = freevar(tp: float64)              ['$0.4']
#     $0.6 = call $0.4(a, func=$0.4, args=[Var(a, numbers.py:225)], kws=(), vararg=None) ['$0.4', '$0.6', 'a']
#     a.1 = $0.6                               ['$0.6', 'a.1']
#     $const0.8 = const(int, 0)                ['$const0.8']
#     $0.9 = b < $const0.8                     ['$0.9', '$const0.8', 'b']
#     branch $0.9, 26, 98                      ['$0.9']
# label 26:
#     $const26.1 = const(bool, True)           ['$const26.1']
#     invert = $const26.1                      ['$const26.1', 'invert']
#     $26.3 = unary(fn=<built-in function neg>, value=b) ['$26.3', 'b']
#     exp = $26.3                              ['$26.3', 'exp']
#     $const26.5 = const(int, 0)               ['$const26.5']
#     $26.6 = exp < $const26.5                 ['$26.6', '$const26.5', 'exp']
#     branch $26.6, 44, 48                     ['$26.6']
# label 44:
#     $44.1 = global(OverflowError: <class 'OverflowError'>) ['$44.1']
#     raise $44.1                              ['$44.1']
# label 48:
#     $48.1 = freevar(is_integer: False)       ['$48.1']
#     branch $48.1, 52, 106                    ['$48.1']
# label 52:
#     $const52.2 = const(int, 0)               ['$const52.2']
#     $52.3 = a.1 == $const52.2                ['$52.3', '$const52.2', 'a.1']
#     branch $52.3, 60, 76                     ['$52.3']
# label 60:
#     $60.1 = freevar(zerodiv_return: False)   ['$60.1']
#     branch $60.1, 64, 68                     ['$60.1']
# label 64:
#     $64.1 = freevar(zerodiv_return: False)   ['$64.1']
#     $64.2 = cast(value=$64.1)                ['$64.1', '$64.2']
#     return $64.2                             ['$64.2']
# label 68:
#     $68.1 = global(ZeroDivisionError: <class 'ZeroDivisionError'>) ['$68.1']
#     $const68.2 = const(str, 0 cannot be raised to a negative power) ['$const68.2']
#     $68.3 = call $68.1($const68.2, func=$68.1, args=[Var($const68.2, numbers.py:237)], kws=(), vararg=None) ['$68.1', '$68.3', '$const68.2']
#     raise $68.3                              ['$68.3']
# label 76:
#     $const76.2 = const(int, 1)               ['$const76.2']
#     $76.3 = a.1 != $const76.2                ['$76.3', '$const76.2', 'a.1']
#     branch $76.3, 84, 106                    ['$76.3']
# label 84:
#     $const84.2 = const(int, -1)              ['$const84.2']
#     $84.3 = a.1 != $const84.2                ['$84.3', '$const84.2', 'a.1']
#     branch $84.3, 92, 106                    ['$84.3']
# label 92:
#     $const92.1 = const(int, 0)               ['$const92.1']
#     $92.2 = cast(value=$const92.1)           ['$92.2', '$const92.1']
#     return $92.2                             ['$92.2']
# label 98:
#     $const98.1 = const(bool, False)          ['$const98.1']
#     invert = $const98.1                      ['$const98.1', 'invert']
#     exp = b                                  ['b', 'exp']
#     jump 106                                 []
# label 106:
#     $const106.2 = const(int, 65536)          ['$const106.2']
#     $106.3 = exp > $const106.2               ['$106.3', '$const106.2', 'exp']
#     branch $106.3, 114, 130                  ['$106.3']
# label 114:
#     $114.1 = global(math: <module 'math' from '/home/dominic/anaconda3/envs/openmm/lib/python3.6/lib-dynload/math.cpython-36m-x86_64-linux-gnu.so'>) ['$114.1']
#     $114.2 = getattr(value=$114.1, attr=pow) ['$114.1', '$114.2']
#     $114.4 = global(float: <class 'float'>)  ['$114.4']
#     $114.6 = call $114.4(b, func=$114.4, args=[Var(b, numbers.py:225)], kws=(), vararg=None) ['$114.4', '$114.6', 'b']
#     $114.7 = call $114.2(a.1, $114.6, func=$114.2, args=[Var(a.1, numbers.py:226), Var($114.6, numbers.py:245)], kws=(), vararg=None) ['$114.2', '$114.6', '$114.7', 'a.1']
#     $114.8 = cast(value=$114.7)              ['$114.7', '$114.8']
#     return $114.8                            ['$114.8']
# label 130:
#     jump 132                                 []
# label 132:
#     $const132.2 = const(int, 0)              ['$const132.2']
#     $132.3 = exp != $const132.2              ['$132.3', '$const132.2', 'exp']
#     branch $132.3, 140, 174                  ['$132.3']
# label 140:
#     $const140.2 = const(int, 1)              ['$const140.2']
#     $140.3 = exp & $const140.2               ['$140.3', '$const140.2', 'exp']
#     branch $140.3, 148, 156                  ['$140.3']
# label 148:
#     $148.3 = inplace_binop(fn=<built-in function imul>, immutable_fn=<built-in function mul>, lhs=r, rhs=a.1, static_lhs=Undefined, static_rhs=Undefined) ['$148.3', 'a.1', 'r']
#     r = $148.3                               ['$148.3', 'r']
#     jump 156                                 []
# label 156:
#     $const156.2 = const(int, 1)              ['$const156.2']
#     $156.3 = inplace_binop(fn=<built-in function irshift>, immutable_fn=<built-in function rshift>, lhs=exp, rhs=$const156.2, static_lhs=Undefined, static_rhs=Undefined) ['$156.3', '$const156.2', 'exp']
#     exp = $156.3                             ['$156.3', 'exp']
#     $156.6 = inplace_binop(fn=<built-in function imul>, immutable_fn=<built-in function mul>, lhs=a.1, rhs=a.1, static_lhs=Undefined, static_rhs=Undefined) ['$156.6', 'a.1', 'a.1']
#     a.1 = $156.6                             ['$156.6', 'a.1']
#     jump 132                                 []
# label 174:
#     jump 176                                 []
# label 176:
#     branch invert, 180, 188                  ['invert']
# label 180:
#     $const180.1 = const(float, 1.0)          ['$const180.1']
#     $180.3 = $const180.1 / r                 ['$180.3', '$const180.1', 'r']
#     $180.4 = cast(value=$180.3)              ['$180.3', '$180.4']
#     return $180.4                            ['$180.4']
# label 188:
#     $188.2 = cast(value=r)                   ['$188.2', 'r']
#     return $188.2                            ['$188.2']
#
# DEBUG:numba.interpreter:label 0:
#     src_ndim = arg(0, name=src_ndim)         ['src_ndim']
#     src_shape = arg(1, name=src_shape)       ['src_shape']
#     dest_ndim = arg(2, name=dest_ndim)       ['dest_ndim']
#     dest_shape = arg(3, name=dest_shape)     ['dest_shape']
#     $0.3 = src_ndim > dest_ndim              ['$0.3', 'dest_ndim', 'src_ndim']
#     branch $0.3, 10, 14                      ['$0.3']
# label 10:
#     $const10.1 = const(int, 0)               ['$const10.1']
#     $10.2 = cast(value=$const10.1)           ['$10.2', '$const10.1']
#     return $10.2                             ['$10.2']
# label 14:
#     $const14.1 = const(int, 0)               ['$const14.1']
#     src_index = $const14.1                   ['$const14.1', 'src_index']
#     $14.4 = dest_ndim - src_ndim             ['$14.4', 'dest_ndim', 'src_ndim']
#     dest_index = $14.4                       ['$14.4', 'dest_index']
#     jump 26                                  []
# label 26:
#     jump 28                                  []
# label 28:
#     $28.3 = src_index < src_ndim             ['$28.3', 'src_index', 'src_ndim']
#     branch $28.3, 36, 122                    ['$28.3']
# label 36:
#     $36.3 = getitem(value=src_shape, index=src_index) ['$36.3', 'src_index', 'src_shape']
#     src_dim_size = $36.3                     ['$36.3', 'src_dim_size']
#     $36.6 = getitem(value=dest_shape, index=dest_index) ['$36.6', 'dest_index', 'dest_shape']
#     dest_dim_size = $36.6                    ['$36.6', 'dest_dim_size']
#     $const36.8 = const(int, 1)               ['$const36.8']
#     $36.9 = dest_dim_size != $const36.8      ['$36.9', '$const36.8', 'dest_dim_size']
#     branch $36.9, 60, 88                     ['$36.9']
# label 60:
#     $60.3 = src_dim_size != dest_dim_size    ['$60.3', 'dest_dim_size', 'src_dim_size']
#     branch $60.3, 68, 104                    ['$60.3']
# label 68:
#     $const68.2 = const(int, 1)               ['$const68.2']
#     $68.3 = src_dim_size != $const68.2       ['$68.3', '$const68.2', 'src_dim_size']
#     branch $68.3, 76, 104                    ['$68.3']
# label 76:
#     $const76.2 = const(int, 1)               ['$const76.2']
#     $76.3 = dest_index + $const76.2          ['$76.3', '$const76.2', 'dest_index']
#     $76.4 = unary(fn=<built-in function neg>, value=$76.3) ['$76.3', '$76.4']
#     $76.5 = cast(value=$76.4)                ['$76.4', '$76.5']
#     return $76.5                             ['$76.5']
# label 88:
#     $const88.2 = const(int, 1)               ['$const88.2']
#     $88.3 = src_dim_size != $const88.2       ['$88.3', '$const88.2', 'src_dim_size']
#     branch $88.3, 96, 104                    ['$88.3']
# label 96:
#     dest_shape[dest_index] = src_dim_size    ['dest_index', 'dest_shape', 'src_dim_size']
#     jump 104                                 []
# label 104:
#     $const104.2 = const(int, 1)              ['$const104.2']
#     $104.3 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=src_index, rhs=$const104.2, static_lhs=Undefined, static_rhs=Undefined) ['$104.3', '$const104.2', 'src_index']
#     src_index = $104.3                       ['$104.3', 'src_index']
#     $const104.5 = const(int, 1)              ['$const104.5']
#     $104.6 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=dest_index, rhs=$const104.5, static_lhs=Undefined, static_rhs=Undefined) ['$104.6', '$const104.5', 'dest_index']
#     dest_index = $104.6                      ['$104.6', 'dest_index']
#     jump 28                                  []
# label 122:
#     jump 124                                 []
# label 124:
#     $124.2 = cast(value=dest_index)          ['$124.2', 'dest_index']
#     return $124.2                            ['$124.2']
#
# DEBUG:numba.interpreter:label 0:
#     bond_position = arg(0, name=bond_position) ['bond_position']
#     angle_position = arg(1, name=angle_position) ['angle_position']
#     torsion_position = arg(2, name=torsion_position) ['torsion_position']
#     internal_coordinates = arg(3, name=internal_coordinates) ['internal_coordinates']
#     $const0.2 = const(int, 0)                ['$const0.2']
#     $0.3 = getitem(value=internal_coordinates, index=$const0.2) ['$0.3', '$const0.2', 'internal_coordinates']
#     r = $0.3                                 ['$0.3', 'r']
#     $const0.5 = const(int, 1)                ['$const0.5']
#     $0.6 = getitem(value=internal_coordinates, index=$const0.5) ['$0.6', '$const0.5', 'internal_coordinates']
#     theta = $0.6                             ['$0.6', 'theta']
#     $const0.8 = const(int, 2)                ['$const0.8']
#     $0.9 = getitem(value=internal_coordinates, index=$const0.8) ['$0.9', '$const0.8', 'internal_coordinates']
#     phi = $0.9                               ['$0.9', 'phi']
#     $0.12 = angle_position - bond_position   ['$0.12', 'angle_position', 'bond_position']
#     a = $0.12                                ['$0.12', 'a']
#     $0.15 = angle_position - torsion_position ['$0.15', 'angle_position', 'torsion_position']
#     b = $0.15                                ['$0.15', 'b']
#     $0.17 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.17']
#     $0.19 = call $0.17(a, func=$0.17, args=[Var(a, coordinate_numba.py:50)], kws=(), vararg=None) ['$0.17', '$0.19', 'a']
#     $0.20 = a / $0.19                        ['$0.19', '$0.20', 'a']
#     a_u = $0.20                              ['$0.20', 'a_u']
#     $0.22 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.22']
#     $0.24 = call $0.22(b, func=$0.22, args=[Var(b, coordinate_numba.py:51)], kws=(), vararg=None) ['$0.22', '$0.24', 'b']
#     $0.25 = b / $0.24                        ['$0.24', '$0.25', 'b']
#     b_u = $0.25                              ['$0.25', 'b_u']
#     $0.28 = r * a_u                          ['$0.28', 'a_u', 'r']
#     d_r = $0.28                              ['$0.28', 'd_r']
#     $0.29 = global(_cross_vec3: CPUDispatcher(<function _cross_vec3 at 0x7f1118879378>)) ['$0.29']
#     $0.32 = call $0.29(a_u, b_u, func=$0.29, args=[Var(a_u, coordinate_numba.py:53), Var(b_u, coordinate_numba.py:54)], kws=(), vararg=None) ['$0.29', '$0.32', 'a_u', 'b_u']
#     normal = $0.32                           ['$0.32', 'normal']
#     $0.34 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.34']
#     $0.36 = call $0.34(normal, func=$0.34, args=[Var(normal, coordinate_numba.py:58)], kws=(), vararg=None) ['$0.34', '$0.36', 'normal']
#     $0.37 = normal / $0.36                   ['$0.36', '$0.37', 'normal']
#     angle_axis = $0.37                       ['$0.37', 'angle_axis']
#     $0.38 = global(_rotation_matrix: CPUDispatcher(<function _rotation_matrix at 0x7f1118057510>)) ['$0.38']
#     $0.41 = call $0.38(angle_axis, theta, func=$0.38, args=[Var(angle_axis, coordinate_numba.py:61), Var(theta, coordinate_numba.py:48)], kws=(), vararg=None) ['$0.38', '$0.41', 'angle_axis', 'theta']
#     angle_rotation_matrix = $0.41            ['$0.41', 'angle_rotation_matrix']
#     $0.42 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.42']
#     $0.43 = getattr(value=$0.42, attr=dot)   ['$0.42', '$0.43']
#     $0.46 = call $0.43(angle_rotation_matrix, d_r, func=$0.43, args=[Var(angle_rotation_matrix, coordinate_numba.py:62), Var(d_r, coordinate_numba.py:56)], kws=(), vararg=None) ['$0.43', '$0.46', 'angle_rotation_matrix', 'd_r']
#     d_ang = $0.46                            ['$0.46', 'd_ang']
#     torsion_axis = a_u                       ['a_u', 'torsion_axis']
#     $0.48 = global(_rotation_matrix: CPUDispatcher(<function _rotation_matrix at 0x7f1118057510>)) ['$0.48']
#     $0.51 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.51']
#     $0.52 = getattr(value=$0.51, attr=pi)    ['$0.51', '$0.52']
#     $0.53 = phi + $0.52                      ['$0.52', '$0.53', 'phi']
#     $0.54 = unary(fn=<built-in function neg>, value=$0.53) ['$0.53', '$0.54']
#     $0.55 = call $0.48(torsion_axis, $0.54, func=$0.48, args=[Var(torsion_axis, coordinate_numba.py:68), Var($0.54, coordinate_numba.py:69)], kws=(), vararg=None) ['$0.48', '$0.54', '$0.55', 'torsion_axis']
#     torsion_rotation_matrix = $0.55          ['$0.55', 'torsion_rotation_matrix']
#     $0.56 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.56']
#     $0.57 = getattr(value=$0.56, attr=dot)   ['$0.56', '$0.57']
#     $0.60 = call $0.57(torsion_rotation_matrix, d_ang, func=$0.57, args=[Var(torsion_rotation_matrix, coordinate_numba.py:69), Var(d_ang, coordinate_numba.py:65)], kws=(), vararg=None) ['$0.57', '$0.60', 'd_ang', 'torsion_rotation_matrix']
#     d_torsion = $0.60                        ['$0.60', 'd_torsion']
#     $0.63 = bond_position + d_torsion        ['$0.63', 'bond_position', 'd_torsion']
#     xyz = $0.63                              ['$0.63', 'xyz']
#     $0.65 = cast(value=xyz)                  ['$0.65', 'xyz']
#     return $0.65                             ['$0.65']
#
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/perses-0.4.0-py3.6.egg/perses/rjmc/coordinate_numba.py:65: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 1d, C))
#   d_ang = np.dot(angle_rotation_matrix, d_r)
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/perses-0.4.0-py3.6.egg/perses/rjmc/coordinate_numba.py:71: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 2d, A), array(float64, 1d, C))
#   d_torsion = np.dot(torsion_rotation_matrix, d_ang)
# DEBUG:numba.interpreter:label 0:
#     angle_position = arg(0, name=angle_position) ['angle_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     $0.3 = angle_position - bond_position    ['$0.3', 'angle_position', 'bond_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     angle_position = arg(0, name=angle_position) ['angle_position']
#     torsion_position = arg(1, name=torsion_position) ['torsion_position']
#     $0.3 = angle_position - torsion_position ['$0.3', 'angle_position', 'torsion_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_19 = arg(0, name=_0_19)               ['_0_19']
#     a = arg(1, name=a)                       ['a']
#     $0.3 = a / _0_19                         ['$0.3', '_0_19', 'a']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_24 = arg(0, name=_0_24)               ['_0_24']
#     b = arg(1, name=b)                       ['b']
#     $0.3 = b / _0_24                         ['$0.3', '_0_24', 'b']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     a_u = arg(0, name=a_u)                   ['a_u']
#     r = arg(1, name=r)                       ['r']
#     $0.3 = r * a_u                           ['$0.3', 'a_u', 'r']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_36 = arg(0, name=_0_36)               ['_0_36']
#     normal = arg(1, name=normal)             ['normal']
#     $0.3 = normal / _0_36                    ['$0.3', '_0_36', 'normal']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     $0.2 = getattr(value=a, attr=shape)      ['$0.2', 'a']
#     $0.5 = exhaust_iter(value=$0.2, count=2) ['$0.2', '$0.5']
#     $0.3 = static_getitem(value=$0.5, index=0, index_var=None) ['$0.3', '$0.5']
#     $0.4 = static_getitem(value=$0.5, index=1, index_var=None) ['$0.4', '$0.5']
#     m = $0.3                                 ['$0.3', 'm']
#     n = $0.4                                 ['$0.4', 'n']
#     $0.7 = getattr(value=b, attr=shape)      ['$0.7', 'b']
#     $0.9 = exhaust_iter(value=$0.7, count=1) ['$0.7', '$0.9']
#     $0.8 = static_getitem(value=$0.9, index=0, index_var=None) ['$0.8', '$0.9']
#     _n = $0.8                                ['$0.8', '_n']
#     $0.10 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.10']
#     $0.11 = getattr(value=$0.10, attr=empty) ['$0.10', '$0.11']
#     $0.13 = build_tuple(items=[Var(m, linalg.py:486)]) ['$0.13', 'm']
#     $0.15 = getattr(value=a, attr=dtype)     ['$0.15', 'a']
#     $0.16 = call $0.11($0.13, $0.15, func=$0.11, args=[Var($0.13, linalg.py:488), Var($0.15, linalg.py:488)], kws=(), vararg=None) ['$0.11', '$0.13', '$0.15', '$0.16']
#     out = $0.16                              ['$0.16', 'out']
#     $0.17 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.17']
#     $0.18 = getattr(value=$0.17, attr=dot)   ['$0.17', '$0.18']
#     $0.22 = call $0.18(a, b, out, func=$0.18, args=[Var(a, linalg.py:486), Var(b, linalg.py:486), Var(out, linalg.py:488)], kws=(), vararg=None) ['$0.18', '$0.22', 'a', 'b', 'out']
#     $0.23 = cast(value=$0.22)                ['$0.22', '$0.23']
#     return $0.23                             ['$0.23']
#
# DEBUG:numba.interpreter:label 0:
#     a = arg(0, name=a)                       ['a']
#     b = arg(1, name=b)                       ['b']
#     out = arg(2, name=out)                   ['out']
#     $0.2 = getattr(value=a, attr=shape)      ['$0.2', 'a']
#     $0.5 = exhaust_iter(value=$0.2, count=2) ['$0.2', '$0.5']
#     $0.3 = static_getitem(value=$0.5, index=0, index_var=None) ['$0.3', '$0.5']
#     $0.4 = static_getitem(value=$0.5, index=1, index_var=None) ['$0.4', '$0.5']
#     m = $0.3                                 ['$0.3', 'm']
#     _n = $0.4                                ['$0.4', '_n']
#     $0.7 = getattr(value=b, attr=shape)      ['$0.7', 'b']
#     $0.9 = exhaust_iter(value=$0.7, count=1) ['$0.7', '$0.9']
#     $0.8 = static_getitem(value=$0.9, index=0, index_var=None) ['$0.8', '$0.9']
#     n = $0.8                                 ['$0.8', 'n']
#     $0.12 = n != _n                          ['$0.12', '_n', 'n']
#     branch $0.12, 28, 36                     ['$0.12']
# label 28:
#     $28.1 = global(ValueError: <class 'ValueError'>) ['$28.1']
#     $const28.2 = const(str, incompatible array sizes for np.dot(a, b) (matrix * vector)) ['$const28.2']
#     $28.3 = call $28.1($const28.2, func=$28.1, args=[Var($const28.2, linalg.py:573)], kws=(), vararg=None) ['$28.1', '$28.3', '$const28.2']
#     raise $28.3                              ['$28.3']
# label 36:
#     $36.2 = getattr(value=out, attr=shape)   ['$36.2', 'out']
#     $36.4 = build_tuple(items=[Var(m, linalg.py:570)]) ['$36.4', 'm']
#     $36.5 = $36.2 != $36.4                   ['$36.2', '$36.4', '$36.5']
#     branch $36.5, 48, 56                     ['$36.5']
# label 48:
#     $48.1 = global(ValueError: <class 'ValueError'>) ['$48.1']
#     $const48.2 = const(str, incompatible output array size for np.dot(a, b, out) (matrix * vector)) ['$const48.2']
#     $48.3 = call $48.1($const48.2, func=$48.1, args=[Var($const48.2, linalg.py:576)], kws=(), vararg=None) ['$48.1', '$48.3', '$const48.2']
#     raise $48.3                              ['$48.3']
# label 56:
#     $const56.1 = const(NoneType, None)       ['$const56.1']
#     $56.2 = cast(value=$const56.1)           ['$56.2', '$const56.1']
#     return $56.2                             ['$56.2']
#
# DEBUG:numba.interpreter:label 0:
#     bond_position = arg(0, name=bond_position) ['bond_position']
#     d_torsion = arg(1, name=d_torsion)       ['d_torsion']
#     $0.3 = bond_position + d_torsion         ['$0.3', 'bond_position', 'd_torsion']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     bond_position = arg(0, name=bond_position) ['bond_position']
#     angle_position = arg(1, name=angle_position) ['angle_position']
#     torsion_position = arg(2, name=torsion_position) ['torsion_position']
#     internal_coordinates = arg(3, name=internal_coordinates) ['internal_coordinates']
#     phi_set = arg(4, name=phi_set)           ['phi_set']
#     $0.1 = global(len: <built-in function len>) ['$0.1']
#     $0.3 = call $0.1(phi_set, func=$0.1, args=[Var(phi_set, coordinate_numba.py:80)], kws=(), vararg=None) ['$0.1', '$0.3', 'phi_set']
#     n_phis = $0.3                            ['$0.3', 'n_phis']
#     $0.4 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.4']
#     $0.5 = getattr(value=$0.4, attr=zeros)   ['$0.4', '$0.5']
#     $const0.7 = const(int, 3)                ['$const0.7']
#     $0.8 = build_tuple(items=[Var(n_phis, coordinate_numba.py:80), Var($const0.7, coordinate_numba.py:81)]) ['$0.8', '$const0.7', 'n_phis']
#     $0.9 = call $0.5($0.8, func=$0.5, args=[Var($0.8, coordinate_numba.py:81)], kws=(), vararg=None) ['$0.5', '$0.8', '$0.9']
#     xyzs = $0.9                              ['$0.9', 'xyzs']
#     jump 24                                  []
# label 24:
#     jump 26                                  []
# label 26:
#     $26.1 = global(range: <class 'range'>)   ['$26.1']
#     $26.3 = call $26.1(n_phis, func=$26.1, args=[Var(n_phis, coordinate_numba.py:80)], kws=(), vararg=None) ['$26.1', '$26.3', 'n_phis']
#     $26.4 = getiter(value=$26.3)             ['$26.3', '$26.4']
#     $phi34.1 = $26.4                         ['$26.4', '$phi34.1']
#     jump 34                                  []
# label 34:
#     $34.2 = iternext(value=$phi34.1)         ['$34.2', '$phi34.1']
#     $34.3 = pair_first(value=$34.2)          ['$34.2', '$34.3']
#     $34.4 = pair_second(value=$34.2)         ['$34.2', '$34.4']
#     $phi36.1 = $34.3                         ['$34.3', '$phi36.1']
#     $phi70.1 = $34.3                         ['$34.3', '$phi70.1']
#     $phi70.2 = $phi34.1                      ['$phi34.1', '$phi70.2']
#     branch $34.4, 36, 70                     ['$34.4']
# label 36:
#     i = $phi36.1                             ['$phi36.1', 'i']
#     $36.4 = getitem(value=phi_set, index=i)  ['$36.4', 'i', 'phi_set']
#     $const36.6 = const(int, 2)               ['$const36.6']
#     internal_coordinates[$const36.6] = $36.4 ['$36.4', '$const36.6', 'internal_coordinates']
#     $36.7 = global(internal_to_cartesian: CPUDispatcher(<function internal_to_cartesian at 0x7f11180daea0>)) ['$36.7']
#     $36.12 = call $36.7(bond_position, angle_position, torsion_position, internal_coordinates, func=$36.7, args=[Var(bond_position, coordinate_numba.py:80), Var(angle_position, coordinate_numba.py:80), Var(torsion_position, coordinate_numba.py:80), Var(internal_coordinates, coordinate_numba.py:80)], kws=(), vararg=None) ['$36.12', '$36.7', 'angle_position', 'bond_position', 'internal_coordinates', 'torsion_position']
#     xyzs[i] = $36.12                         ['$36.12', 'i', 'xyzs']
#     jump 34                                  []
# label 70:
#     jump 72                                  []
# label 72:
#     $72.2 = cast(value=xyzs)                 ['$72.2', 'xyzs']
#     return $72.2                             ['$72.2']
#
# DEBUG:numba.interpreter:label 0:
#     atom_position = arg(0, name=atom_position) ['atom_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     angle_position = arg(2, name=angle_position) ['angle_position']
#     $0.3 = atom_position - bond_position     ['$0.3', 'atom_position', 'bond_position']
#     a = $0.3                                 ['$0.3', 'a']
#     $0.6 = angle_position - bond_position    ['$0.6', 'angle_position', 'bond_position']
#     b = $0.6                                 ['$0.6', 'b']
#     $0.8 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.8']
#     $0.10 = call $0.8(a, func=$0.8, args=[Var(a, coordinate_numba.py:89)], kws=(), vararg=None) ['$0.10', '$0.8', 'a']
#     $0.11 = a / $0.10                        ['$0.10', '$0.11', 'a']
#     a_u = $0.11                              ['$0.11', 'a_u']
#     $0.13 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.13']
#     $0.15 = call $0.13(b, func=$0.13, args=[Var(b, coordinate_numba.py:90)], kws=(), vararg=None) ['$0.13', '$0.15', 'b']
#     $0.16 = b / $0.15                        ['$0.15', '$0.16', 'b']
#     b_u = $0.16                              ['$0.16', 'b_u']
#     $0.17 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.17']
#     $0.18 = getattr(value=$0.17, attr=dot)   ['$0.17', '$0.18']
#     $0.21 = call $0.18(a_u, b_u, func=$0.18, args=[Var(a_u, coordinate_numba.py:91), Var(b_u, coordinate_numba.py:92)], kws=(), vararg=None) ['$0.18', '$0.21', 'a_u', 'b_u']
#     cos_theta = $0.21                        ['$0.21', 'cos_theta']
#     $const0.23 = const(float, 1.0)           ['$const0.23']
#     $0.24 = cos_theta > $const0.23           ['$0.24', '$const0.23', 'cos_theta']
#     branch $0.24, 62, 68                     ['$0.24']
# label 62:
#     $const62.1 = const(float, 1.0)           ['$const62.1']
#     cos_theta = $const62.1                   ['$const62.1', 'cos_theta']
#     jump 80                                  []
# label 68:
#     $const68.2 = const(float, -1.0)          ['$const68.2']
#     $68.3 = cos_theta < $const68.2           ['$68.3', '$const68.2', 'cos_theta']
#     branch $68.3, 76, 80                     ['$68.3']
# label 76:
#     $const76.1 = const(float, -1.0)          ['$const76.1']
#     cos_theta = $const76.1                   ['$const76.1', 'cos_theta']
#     jump 80                                  []
# label 80:
#     $80.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$80.1']
#     $80.2 = getattr(value=$80.1, attr=arccos) ['$80.1', '$80.2']
#     $80.4 = call $80.2(cos_theta, func=$80.2, args=[Var(cos_theta, coordinate_numba.py:95)], kws=(), vararg=None) ['$80.2', '$80.4', 'cos_theta']
#     theta = $80.4                            ['$80.4', 'theta']
#     $80.6 = cast(value=theta)                ['$80.6', 'theta']
#     return $80.6                             ['$80.6']
#
# DEBUG:numba.interpreter:label 0:
#     atom_position = arg(0, name=atom_position) ['atom_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     $0.3 = atom_position - bond_position     ['$0.3', 'atom_position', 'bond_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     angle_position = arg(0, name=angle_position) ['angle_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     $0.3 = angle_position - bond_position    ['$0.3', 'angle_position', 'bond_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_10 = arg(0, name=_0_10)               ['_0_10']
#     a = arg(1, name=a)                       ['a']
#     $0.3 = a / _0_10                         ['$0.3', '_0_10', 'a']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_15 = arg(0, name=_0_15)               ['_0_15']
#     b = arg(1, name=b)                       ['b']
#     $0.3 = b / _0_15                         ['$0.3', '_0_15', 'b']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     atom_position = arg(0, name=atom_position) ['atom_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     angle_position = arg(2, name=angle_position) ['angle_position']
#     torsion_position = arg(3, name=torsion_position) ['torsion_position']
#     $0.3 = atom_position - bond_position     ['$0.3', 'atom_position', 'bond_position']
#     a = $0.3                                 ['$0.3', 'a']
#     $0.6 = angle_position - bond_position    ['$0.6', 'angle_position', 'bond_position']
#     b = $0.6                                 ['$0.6', 'b']
#     $0.9 = angle_position - torsion_position ['$0.9', 'angle_position', 'torsion_position']
#     c = $0.9                                 ['$0.9', 'c']
#     $0.11 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.11']
#     $0.13 = call $0.11(a, func=$0.11, args=[Var(a, coordinate_numba.py:106)], kws=(), vararg=None) ['$0.11', '$0.13', 'a']
#     $0.14 = a / $0.13                        ['$0.13', '$0.14', 'a']
#     a_u = $0.14                              ['$0.14', 'a_u']
#     $0.16 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.16']
#     $0.18 = call $0.16(b, func=$0.16, args=[Var(b, coordinate_numba.py:107)], kws=(), vararg=None) ['$0.16', '$0.18', 'b']
#     $0.19 = b / $0.18                        ['$0.18', '$0.19', 'b']
#     b_u = $0.19                              ['$0.19', 'b_u']
#     $0.21 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.21']
#     $0.23 = call $0.21(c, func=$0.21, args=[Var(c, coordinate_numba.py:109)], kws=(), vararg=None) ['$0.21', '$0.23', 'c']
#     $0.24 = c / $0.23                        ['$0.23', '$0.24', 'c']
#     c_u = $0.24                              ['$0.24', 'c_u']
#     $0.25 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$0.25']
#     $0.27 = call $0.25(a, func=$0.25, args=[Var(a, coordinate_numba.py:106)], kws=(), vararg=None) ['$0.25', '$0.27', 'a']
#     r = $0.27                                ['$0.27', 'r']
#     $0.28 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$0.28']
#     $0.29 = getattr(value=$0.28, attr=dot)   ['$0.28', '$0.29']
#     $0.32 = call $0.29(a_u, b_u, func=$0.29, args=[Var(a_u, coordinate_numba.py:110), Var(b_u, coordinate_numba.py:111)], kws=(), vararg=None) ['$0.29', '$0.32', 'a_u', 'b_u']
#     cos_theta = $0.32                        ['$0.32', 'cos_theta']
#     $const0.34 = const(float, 1.0)           ['$const0.34']
#     $0.35 = cos_theta > $const0.34           ['$0.35', '$const0.34', 'cos_theta']
#     branch $0.35, 90, 96                     ['$0.35']
# label 90:
#     $const90.1 = const(float, 1.0)           ['$const90.1']
#     cos_theta = $const90.1                   ['$const90.1', 'cos_theta']
#     jump 108                                 []
# label 96:
#     $const96.2 = const(float, -1.0)          ['$const96.2']
#     $96.3 = cos_theta < $const96.2           ['$96.3', '$const96.2', 'cos_theta']
#     branch $96.3, 104, 108                   ['$96.3']
# label 104:
#     $const104.1 = const(float, -1.0)         ['$const104.1']
#     cos_theta = $const104.1                  ['$const104.1', 'cos_theta']
#     jump 108                                 []
# label 108:
#     $108.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$108.1']
#     $108.2 = getattr(value=$108.1, attr=arccos) ['$108.1', '$108.2']
#     $108.4 = call $108.2(cos_theta, func=$108.2, args=[Var(cos_theta, coordinate_numba.py:118)], kws=(), vararg=None) ['$108.2', '$108.4', 'cos_theta']
#     theta = $108.4                           ['$108.4', 'theta']
#     $108.5 = global(_cross_vec3: CPUDispatcher(<function _cross_vec3 at 0x7f1118879378>)) ['$108.5']
#     $108.8 = call $108.5(a_u, b_u, func=$108.5, args=[Var(a_u, coordinate_numba.py:110), Var(b_u, coordinate_numba.py:111)], kws=(), vararg=None) ['$108.5', '$108.8', 'a_u', 'b_u']
#     plane1 = $108.8                          ['$108.8', 'plane1']
#     $108.9 = global(_cross_vec3: CPUDispatcher(<function _cross_vec3 at 0x7f1118879378>)) ['$108.9']
#     $108.12 = call $108.9(b_u, c_u, func=$108.9, args=[Var(b_u, coordinate_numba.py:111), Var(c_u, coordinate_numba.py:112)], kws=(), vararg=None) ['$108.12', '$108.9', 'b_u', 'c_u']
#     plane2 = $108.12                         ['$108.12', 'plane2']
#     $108.13 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$108.13']
#     $108.14 = getattr(value=$108.13, attr=dot) ['$108.13', '$108.14']
#     $108.17 = call $108.14(plane1, plane2, func=$108.14, args=[Var(plane1, coordinate_numba.py:126), Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None) ['$108.14', '$108.17', 'plane1', 'plane2']
#     $108.18 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$108.18']
#     $108.20 = call $108.18(plane1, func=$108.18, args=[Var(plane1, coordinate_numba.py:126)], kws=(), vararg=None) ['$108.18', '$108.20', 'plane1']
#     $108.21 = global(_norm: CPUDispatcher(<function _norm at 0x7f1118251f28>)) ['$108.21']
#     $108.23 = call $108.21(plane2, func=$108.21, args=[Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None) ['$108.21', '$108.23', 'plane2']
#     $108.24 = $108.20 * $108.23              ['$108.20', '$108.23', '$108.24']
#     $108.25 = $108.17 / $108.24              ['$108.17', '$108.24', '$108.25']
#     cos_phi = $108.25                        ['$108.25', 'cos_phi']
#     $const108.27 = const(float, -1.0)        ['$const108.27']
#     $108.28 = cos_phi < $const108.27         ['$108.28', '$const108.27', 'cos_phi']
#     branch $108.28, 174, 180                 ['$108.28']
# label 174:
#     $const174.1 = const(float, -1.0)         ['$const174.1']
#     cos_phi = $const174.1                    ['$const174.1', 'cos_phi']
#     jump 192                                 []
# label 180:
#     $const180.2 = const(float, 1.0)          ['$const180.2']
#     $180.3 = cos_phi > $const180.2           ['$180.3', '$const180.2', 'cos_phi']
#     branch $180.3, 188, 192                  ['$180.3']
# label 188:
#     $const188.1 = const(float, 1.0)          ['$const188.1']
#     cos_phi = $const188.1                    ['$const188.1', 'cos_phi']
#     jump 192                                 []
# label 192:
#     $192.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$192.1']
#     $192.2 = getattr(value=$192.1, attr=arccos) ['$192.1', '$192.2']
#     $192.4 = call $192.2(cos_phi, func=$192.2, args=[Var(cos_phi, coordinate_numba.py:129)], kws=(), vararg=None) ['$192.2', '$192.4', 'cos_phi']
#     phi = $192.4                             ['$192.4', 'phi']
#     $192.5 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$192.5']
#     $192.6 = getattr(value=$192.5, attr=dot) ['$192.5', '$192.6']
#     $192.9 = call $192.6(a, plane2, func=$192.6, args=[Var(a, coordinate_numba.py:106), Var(plane2, coordinate_numba.py:127)], kws=(), vararg=None) ['$192.6', '$192.9', 'a', 'plane2']
#     $const192.10 = const(int, 0)             ['$const192.10']
#     $192.11 = $192.9 <= $const192.10         ['$192.11', '$192.9', '$const192.10']
#     branch $192.11, 218, 224                 ['$192.11']
# label 218:
#     $218.2 = unary(fn=<built-in function neg>, value=phi) ['$218.2', 'phi']
#     phi = $218.2                             ['$218.2', 'phi']
#     jump 224                                 []
# label 224:
#     $224.1 = global(np: <module 'numpy' from '/home/dominic/.local/lib/python3.6/site-packages/numpy-1.17.2-py3.6-linux-x86_64.egg/numpy/__init__.py'>) ['$224.1']
#     $224.2 = getattr(value=$224.1, attr=array) ['$224.1', '$224.2']
#     $224.6 = build_list(items=[Var(r, coordinate_numba.py:115), Var(theta, coordinate_numba.py:123), Var(phi, coordinate_numba.py:135)]) ['$224.6', 'phi', 'r', 'theta']
#     $224.7 = call $224.2($224.6, func=$224.2, args=[Var($224.6, coordinate_numba.py:140)], kws=(), vararg=None) ['$224.2', '$224.6', '$224.7']
#     $224.8 = cast(value=$224.7)              ['$224.7', '$224.8']
#     return $224.8                            ['$224.8']
#
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/perses-0.4.0-py3.6.egg/perses/rjmc/coordinate_numba.py:129: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, A), array(float64, 1d, A))
#   cos_phi = np.dot(plane1, plane2) / (_norm(plane1)*_norm(plane2))
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/perses-0.4.0-py3.6.egg/perses/rjmc/coordinate_numba.py:137: NumbaPerformanceWarning: np.dot() is faster on contiguous arrays, called on (array(float64, 1d, C), array(float64, 1d, A))
#   if np.dot(a, plane2) <= 0:
# DEBUG:numba.interpreter:label 0:
#     atom_position = arg(0, name=atom_position) ['atom_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     $0.3 = atom_position - bond_position     ['$0.3', 'atom_position', 'bond_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     angle_position = arg(0, name=angle_position) ['angle_position']
#     bond_position = arg(1, name=bond_position) ['bond_position']
#     $0.3 = angle_position - bond_position    ['$0.3', 'angle_position', 'bond_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     angle_position = arg(0, name=angle_position) ['angle_position']
#     torsion_position = arg(1, name=torsion_position) ['torsion_position']
#     $0.3 = angle_position - torsion_position ['$0.3', 'angle_position', 'torsion_position']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_13 = arg(0, name=_0_13)               ['_0_13']
#     a = arg(1, name=a)                       ['a']
#     $0.3 = a / _0_13                         ['$0.3', '_0_13', 'a']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_18 = arg(0, name=_0_18)               ['_0_18']
#     b = arg(1, name=b)                       ['b']
#     $0.3 = b / _0_18                         ['$0.3', '_0_18', 'b']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
#
# DEBUG:numba.interpreter:label 0:
#     _0_23 = arg(0, name=_0_23)               ['_0_23']
#     c = arg(1, name=c)                       ['c']
#     $0.3 = c / _0_23                         ['$0.3', '_0_23', 'c']
#     $0.4 = cast(value=$0.3)                  ['$0.3', '$0.4']
#     return $0.4                              ['$0.4']
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU
# conducting subsequent work with the following platform: CPU

# %%
mapping_strength = 'default'
import pickle
phase = 'vacuum'
from perses.utils.smallmolecules import render_atom_mapping
graph = generate_fully_connected_perturbation_graph(phase = phase)
print(f"graph edges: {graph.edges()}")
# for pair in graph.edges():
#     for phase in ['vac', 'sol']:
#         print("Seralizing the system to ", f"{pair}_{phase}" + ".xml")
#         with open(f"{pair[0]}_{pair[1]}.{phase}.{mapping_strength}_map.xml", 'w') as f:
#             hybrid_system = graph.edges[pair][f"{phase}_htf"]._hybrid_system
#             f.write(openmm.openmm.XmlSerializer.serialize(hybrid_system))
        
#         htf = graph.edges[pair][f"{phase}_htf"]
#         htf._topology_proposal._old_networkx_residue.remove_oemols_from_graph()
#         htf._topology_proposal._new_networkx_residue.remove_oemols_from_graph()
#         _map, oldmol, newmol = graph.edges[pair][f"map_oldmol_newmol"]
#         render_atom_mapping(f"{pair[0]}_{pair[1]}.{mapping_strength}_map.png", oldmol, newmol, _map)
#         with open(f"{pair[0]}_{pair[1]}.{phase}.{mapping_strength}_map.pkl", 'wb') as f:
#             pickle.dump(htf, f)
# Out:
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 14
# INFO:geometry:Atom index proposal order is [10, 15, 16, 18, 24, 20, 22, 25, 17, 12, 23, 11, 19, 21]
# INFO:geometry:omitted_bonds: [(20, 22)]
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 16 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 54 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 82 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 154 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (PHE)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (PHE)>, <Atom 10 (CB) of chain 0 residue 1 (PHE)>, <Atom 13 (C) of chain 0 residue 1 (PHE)>, <Atom 6 (N) of chain 0 residue 1 (PHE)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [(20, 22)], 'angles': [(18, 20, 22), (20, 22, 23), (20, 22, 24), (21, 20, 22)], 'torsions': [(15, 24, 22, 20), (16, 18, 20, 22), (18, 20, 22, 23), (18, 20, 22, 24), (19, 18, 20, 22), (20, 22, 24, 25), (21, 20, 22, 23), (21, 20, 22, 24), (18, 22, 20, 21)], '1,4s': [(15, 20), (16, 22), (19, 22), (18, 23), (21, 23), (18, 24), (21, 24), (20, 25)]}
# INFO:geometry:extra torsions: {0: (22, 24, 15, 10, [1, Quantity(value=-0.05926690747810337, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 7]), 1: (22, 24, 15, 16, [1, Quantity(value=3.1352639058829186, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 7]), 2: (24, 15, 16, 18, [1, Quantity(value=-3.12607014738776, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 5]), 3: (10, 15, 16, 18, [1, Quantity(value=0.06780092444542918, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 4]), 4: (15, 16, 18, 20, [1, Quantity(value=3.127339152139995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 6])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -22.78100542555227
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# generating point mutation engine
# generating geometry engine
# making topology proposal
# making geometry proposal from ALA to PHE
# INFO:geometry:There are 14 new atoms
# INFO:geometry:	reduced angle potential = 0.08309671747062661.
# INFO:geometry:	reduced angle potential = 0.15746591096172904.
# INFO:geometry:	reduced angle potential = 0.33560663766135296.
# INFO:geometry:	reduced angle potential = 0.1429475966355321.
# INFO:geometry:	reduced angle potential = 0.028587591855980442.
# INFO:geometry:	reduced angle potential = 0.380745623581824.
# INFO:geometry:	reduced angle potential = 0.045349046232531526.
# INFO:geometry:	reduced angle potential = 0.08503204372485398.
# INFO:geometry:	reduced angle potential = 0.009109665701003015.
# INFO:geometry:	reduced angle potential = 1.5462981939230205.
# INFO:geometry:	reduced angle potential = 0.1923871412672404.
# INFO:geometry:	reduced angle potential = 0.986532359080255.
# INFO:geometry:	reduced angle potential = 0.2689035664921363.
# INFO:geometry:	reduced angle potential = 1.2472758688347914.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	there are 16 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 54 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 82 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 9.116470355218665
# INFO:geometry:total reduced energy added from growth system: 43.80357485657726
# INFO:geometry:final reduced energy 80.53921469756816
# INFO:geometry:sum of energies: 52.92004521179592
# INFO:geometry:magnitude of difference in the energies: 27.619169485772233
# INFO:geometry:Final logp_proposal: 89.64077241086873
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# INFO:geometry:Atom index proposal order is [10, 13, 11, 12]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 14 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# added energy components: [('CustomBondForce', 3.1945015909100904), ('CustomAngleForce', 9.80111865591279), ('CustomTorsionForce', 21.06764623455899), ('CustomBondForce', 9.74030837519539)]
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.08012155678424232.
# INFO:geometry:	reduced angle potential = 7.390951941228323e-11.
# INFO:geometry:	reduced angle potential = 1.2915573155343707e-10.
# INFO:geometry:	reduced angle potential = 3.205828647416432e-13.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 9.116470355218665
# INFO:geometry:total reduced energy added from growth system: 20.672958966061056
# INFO:geometry:final reduced energy 29.78942932127971
# INFO:geometry:sum of energies: 29.78942932127972
# INFO:geometry:magnitude of difference in the energies: 1.0658141036401503e-14
# INFO:geometry:Final logp_proposal: 27.117176516956896
# INFO:geometry:propose: performing forward proposal
# INFO:geometry:propose: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 4
# added energy components: [('CustomBondForce', 0.0005201485038389051), ('CustomAngleForce', 0.4511193951899072), ('CustomTorsionForce', 7.250453392425598), ('CustomBondForce', 12.970866029941712)]
# generating point mutation engine
# generating geometry engine
# making topology proposal
# making geometry proposal from PHE to ALA
# INFO:geometry:Atom index proposal order is [10, 15, 12, 11]
# INFO:geometry:omitted_bonds: []
# INFO:geometry:direction of proposal is forward; creating atoms_with_positions and new positions from old system/topology...
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 9 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 36 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 42 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 98 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (ALA)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (ALA)>, <Atom 10 (CB) of chain 0 residue 1 (ALA)>, <Atom 13 (C) of chain 0 residue 1 (ALA)>, <Atom 6 (N) of chain 0 residue 1 (ALA)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [], 'angles': [], 'torsions': [], '1,4s': []}
# INFO:geometry:extra torsions: {}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -5.78074351579233
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context new positions
# INFO:geometry:There are 4 new atoms
# INFO:geometry:	reduced angle potential = 0.01361520296326.
# INFO:geometry:	reduced angle potential = 0.7099801822902302.
# INFO:geometry:	reduced angle potential = 0.0009741576646291325.
# INFO:geometry:	reduced angle potential = 0.4520768555887913.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	there are 9 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 36 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 42 torsion forces in the no-nonbonded final system
# INFO:geometry:forward final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 9.116470355218665
# INFO:geometry:total reduced energy added from growth system: 26.758765300794938
# INFO:geometry:final reduced energy 35.87523565601359
# INFO:geometry:sum of energies: 35.8752356560136
# INFO:geometry:magnitude of difference in the energies: 1.7763568394002505e-14
# INFO:geometry:Final logp_proposal: 22.427107358027268
# INFO:geometry:logp_reverse: performing reverse proposal
# INFO:geometry:logp_reverse: unique new atoms detected; proceeding to _logp_propose...
# INFO:geometry:Conducting forward proposal...
# INFO:geometry:Computing proposal order with NetworkX...
# INFO:geometry:number of atoms to be placed: 14
# INFO:geometry:Atom index proposal order is [10, 15, 16, 24, 18, 22, 20, 11, 12, 19, 17, 23, 21, 25]
# INFO:geometry:omitted_bonds: [(20, 22)]
# INFO:geometry:direction of proposal is reverse; creating atoms_with_positions from old system/topology
# INFO:geometry:creating growth system...
# INFO:geometry:	creating bond force...
# INFO:geometry:	there are 16 bonds in reference force.
# INFO:geometry:	creating angle force...
# INFO:geometry:	there are 54 angles in reference force.
# INFO:geometry:	creating torsion force...
# INFO:geometry:	creating extra torsions force...
# INFO:geometry:	there are 82 torsions in reference force.
# INFO:geometry:	creating nonbonded force...
# INFO:geometry:		grabbing reference nonbonded method, cutoff, switching function, switching distance...
# INFO:geometry:		creating nonbonded exception force (i.e. custom bond for 1,4s)...
# INFO:geometry:		looping through exceptions calculating growth indices, and adding appropriate interactions to custom bond force.
# INFO:geometry:		there are 154 in the reference Nonbonded force
# WARNING:geometry:					chiral atom <Atom 8 (CA) of chain 0 residue 1 (PHE)> with neighbors [<Atom 9 (HA) of chain 0 residue 1 (PHE)>, <Atom 10 (CB) of chain 0 residue 1 (PHE)>, <Atom 13 (C) of chain 0 residue 1 (PHE)>, <Atom 6 (N) of chain 0 residue 1 (PHE)>] is surrounded by 3 core neighbors.  omitting chirality bias torsion
# INFO:geometry:Neglected angle terms : []
# INFO:geometry:omitted_growth_terms: {'bonds': [(20, 22)], 'angles': [(18, 20, 22), (20, 22, 23), (20, 22, 24), (21, 20, 22)], 'torsions': [(15, 24, 22, 20), (16, 18, 20, 22), (18, 20, 22, 23), (18, 20, 22, 24), (19, 18, 20, 22), (20, 22, 24, 25), (21, 20, 22, 23), (21, 20, 22, 24), (18, 22, 20, 21)], '1,4s': [(15, 20), (16, 22), (19, 22), (18, 23), (21, 23), (18, 24), (21, 24), (20, 25)]}
# INFO:geometry:extra torsions: {0: (22, 24, 15, 10, [1, Quantity(value=-0.05926690747810337, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 6]), 1: (22, 24, 15, 16, [1, Quantity(value=3.1352639058829186, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 6]), 2: (24, 15, 16, 18, [1, Quantity(value=-3.12607014738776, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 5]), 3: (10, 15, 16, 18, [1, Quantity(value=0.06780092444542918, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 5]), 4: (15, 16, 18, 20, [1, Quantity(value=3.127339152139995, unit=radian), Quantity(value=120.0, unit=kilocalorie/mole), 7])}
# INFO:geometry:neglected angle terms include []
# INFO:geometry:log probability choice of torsions and atom order: -21.40905984104609
# INFO:geometry:creating platform, integrators, and contexts; setting growth parameter
# INFO:geometry:setting atoms_with_positions context old positions
# INFO:geometry:There are 14 new atoms
# added energy components: [('CustomBondForce', 0.5738839472034282), ('CustomAngleForce', 5.8032668764732165), ('CustomTorsionForce', 8.095543529715846), ('CustomBondForce', 12.286070947402443)]
# INFO:geometry:	reduced angle potential = 0.0024118077481143753.
# INFO:geometry:	reduced angle potential = 0.15746591096173265.
# INFO:geometry:	reduced angle potential = 0.3356066376613585.
# INFO:geometry:	reduced angle potential = 0.5718917482305678.
# INFO:geometry:	reduced angle potential = 0.14294759663553555.
# INFO:geometry:	reduced angle potential = 0.04534904623253347.
# INFO:geometry:	reduced angle potential = 0.3807456235818296.
# INFO:geometry:	reduced angle potential = 0.986532359080255.
# INFO:geometry:	reduced angle potential = 1.5462981939230103.
# INFO:geometry:	reduced angle potential = 0.949996361990674.
# INFO:geometry:	reduced angle potential = 0.0016455783835879869.
# INFO:geometry:	reduced angle potential = 0.1923871412672439.
# INFO:geometry:	reduced angle potential = 0.4972236052101348.
# INFO:geometry:	reduced angle potential = 0.08503204372485634.
# INFO:geometry:	beginning construction of no_nonbonded final system...
# INFO:geometry:	initial no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	final no-nonbonded final system forces ['HarmonicBondForce', 'HarmonicAngleForce', 'PeriodicTorsionForce', 'NonbondedForce']
# INFO:geometry:	there are 16 bond forces in the no-nonbonded final system
# INFO:geometry:	there are 54 angle forces in the no-nonbonded final system
# INFO:geometry:	there are 82 torsion forces in the no-nonbonded final system
# INFO:geometry:reverse final system defined with 0 neglected angles.
# INFO:geometry:total reduced potential before atom placement: 9.116470355218665
# INFO:geometry:total reduced energy added from growth system: 43.80357485657726
# INFO:geometry:final reduced energy 80.53921469756816
# INFO:geometry:sum of energies: 52.92004521179592
# INFO:geometry:magnitude of difference in the energies: 27.619169485772233
# INFO:geometry:Final logp_proposal: 85.37444111732643
# added energy components: [('CustomBondForce', 3.1945015909100904), ('CustomAngleForce', 9.80111865591279), ('CustomTorsionForce', 21.06764623455899), ('CustomBondForce', 9.74030837519539)]
# graph_edges: [('ALA', 'PHE'), ('PHE', 'ALA')]
# graph edges: [('ALA', 'PHE'), ('PHE', 'ALA')]

# %%
_dict = graph.edges['ALA', 'PHE']

# %%
_dict
# Out:
# {'vacuum_htf': <perses.annihilation.relative.HybridTopologyFactory at 0x7f114fb1de48>,
#  'map_oldmol_newmol': ({},
#   <oechem.OEMol; proxy of <Swig Object of type 'OEMolWrapper *' at 0x7f1117cd8fc0> >,
#   <oechem.OEMol; proxy of <Swig Object of type 'OEMolWrapper *' at 0x7f1117cd8d80> >),
#  'added_subtracted': (71.42274434234949, 20.672958966061046)}

# %%
htf = _dict['vacuum_htf']

# %%
#zero_state_error, one_state_error = validate_endstate_energies(_dict[f'{phase}_htf']._topology_proposal, _dict[f'{phase}_htf'], _dict['added_subtracted'][0], _dict['added_subtracted'][1], beta = 1.0/(kB*temperature), ENERGY_THRESHOLD = ENERGY_THRESHOLD)

# %% [markdown]
# # Hooray!!!!!!!

# %%
def create_new_pdb(topology, positions, output_pdb = 'test_new.pdb'):
    """
    create a pdb of the geometry proposal (only new system)
    """
    import mdtraj as md
    _positions =  np.array(positions.value_in_unit(unit.nanometer))
    print(_positions)
    traj = md.Trajectory(_positions, md.Topology.from_openmm(topology))
    traj.save(output_pdb)

# %%
create_new_pdb(topology = htf._topology_proposal._old_topology, positions = htf._old_positions, output_pdb = 'ALA_old.pdb')
create_new_pdb(topology = htf._topology_proposal._new_topology, positions = htf._new_positions, output_pdb = 'PHE_good.pdb')
# Out:
# [[ 2.0000010e-01  1.0000000e-01 -1.3000000e-07]
#  [ 2.0000010e-01  2.0900000e-01  1.0000000e-08]
#  [ 1.4862640e-01  2.4538490e-01  8.8982400e-02]
#  [ 1.4862590e-01  2.4538520e-01 -8.8982000e-02]
#  [ 3.4274200e-01  2.6407950e-01 -3.0000000e-07]
#  [ 4.3905800e-01  1.8774060e-01 -6.6000000e-07]
#  [ 3.5553754e-01  3.9696488e-01 -3.1000000e-07]
#  [ 2.7331200e-01  4.5561601e-01 -1.3000000e-07]
#  [ 4.8532621e-01  4.6139253e-01 -4.3000000e-07]
#  [ 5.4075960e-01  4.3155388e-01  8.8981520e-02]
#  [ 5.6613044e-01  4.2208425e-01 -1.2321480e-01]
#  [ 5.1232615e-01  4.5213630e-01 -2.1312016e-01]
#  [ 6.6304840e-01  4.7189354e-01 -1.2057907e-01]
#  [ 5.8085401e-01  3.1408724e-01 -1.2413850e-01]
#  [ 4.7126759e-01  6.1294185e-01  1.4000000e-07]
#  [ 3.6006445e-01  6.6527027e-01  6.2000000e-07]
#  [ 5.8460533e-01  6.8348833e-01  2.5000000e-07]
#  [ 6.7370014e-01  6.3591620e-01 -4.0000000e-08]
#  [ 5.8460551e-01  8.2838837e-01  6.2000000e-07]
#  [ 4.8185761e-01  8.6477349e-01  1.0400000e-06]
#  [ 6.3597984e-01  8.6477313e-01  8.8982830e-02]
#  [ 6.3597900e-01  8.6477354e-01 -8.8981870e-02]]
# [[ 2.00000100e-01  1.00000000e-01 -1.30000000e-07]
#  [ 2.00000100e-01  2.09000000e-01  1.00000000e-08]
#  [ 1.48626400e-01  2.45384900e-01  8.89824000e-02]
#  [ 1.48625900e-01  2.45385200e-01 -8.89820000e-02]
#  [ 3.42742000e-01  2.64079500e-01 -3.00000000e-07]
#  [ 4.39058000e-01  1.87740600e-01 -6.60000000e-07]
#  [ 3.55537540e-01  3.96964880e-01 -3.10000000e-07]
#  [ 2.73312000e-01  4.55616010e-01 -1.30000000e-07]
#  [ 4.85326210e-01  4.61392530e-01 -4.30000000e-07]
#  [ 5.40759600e-01  4.31553880e-01  8.89815200e-02]
#  [ 5.65795767e-01  4.11032369e-01 -1.15055031e-01]
#  [ 6.43975045e-01  3.52149566e-01 -6.70777857e-02]
#  [ 5.21098669e-01  3.33337958e-01 -1.77077187e-01]
#  [ 4.71267590e-01  6.12941850e-01  1.40000000e-07]
#  [ 3.60064450e-01  6.65270270e-01  6.20000000e-07]
#  [ 6.41113964e-01  5.15045688e-01 -1.94320574e-01]
#  [ 7.80957602e-01  4.87181747e-01 -2.23543144e-01]
#  [ 8.29102053e-01  4.01644183e-01 -1.78493872e-01]
#  [ 8.56278373e-01  5.87787218e-01 -2.82310218e-01]
#  [ 9.57062210e-01  5.62287600e-01 -3.11574318e-01]
#  [ 7.88494621e-01  7.06662833e-01 -3.13946211e-01]
#  [ 8.41753230e-01  7.74977348e-01 -3.78449293e-01]
#  [ 6.60674334e-01  7.28349215e-01 -3.11641178e-01]
#  [ 6.26195870e-01  8.28934812e-01 -3.30556073e-01]
#  [ 5.84024676e-01  6.33677510e-01 -2.41943360e-01]
#  [ 4.88268297e-01  6.63778220e-01 -2.02085324e-01]
#  [ 5.84605330e-01  6.83488330e-01  2.50000000e-07]
#  [ 6.73700140e-01  6.35916200e-01 -4.00000000e-08]
#  [ 5.84605510e-01  8.28388370e-01  6.20000000e-07]
#  [ 4.81857610e-01  8.64773490e-01  1.04000000e-06]
#  [ 6.35979840e-01  8.64773130e-01  8.89828300e-02]
#  [ 6.35979000e-01  8.64773540e-01 -8.89818700e-02]]

# %%
import mdtraj as md

# %%
top = md.Topology().from_openmm(htf._topology_proposal._new_topology)

# %%
table, bonds = top.to_dataframe()

# %%
table

# %%
bonds
