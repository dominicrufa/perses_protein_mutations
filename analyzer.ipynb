# %% [markdown]
# # Analyzer

# %%
from pymbar import timeseries
from pymbar import MBAR
from perses.analysis import utils
import os
from openmmtools.multistate import MultiStateReporter, MultiStateSamplerAnalyzer
import networkx as nx
from itertools import combinations 
import time

# %%
phases = ['vac', 'sol']
residues = ['ALA', 'CYS', 'SER', 'THR']
graphs = {phase: nx.DiGraph(title = f'{phase} thermocycle') for phase in phases}
for graph in graphs.values():
    for residue in residues:
        graph.add_node(residue)

# %%
for phase in phases:
    graph = graphs[phase]
    for peptide_transform in combinations(residues, 2):
        for direct in [peptide_transform, peptide_transform[::-1]]:
            try:
                reporter = MultiStateReporter(f"{direct[0]}_{direct[1]}.{phase}.default_map.nc")
                analyzer = MultiStateSamplerAnalyzer(reporter)
                f_ij, df_ij = analyzer.get_free_energy()
                dg = f_ij[0,-1]
                ddg = df_ij[0,-1]**2
                graph.add_edge(*direct, dg = dg, ddg = ddg)
                
            except Exception as e:
                print(e)
            time.sleep(3)

# %%
graphs
for graph in graphs.values():
    for edge in graph.edges(data = True):
        _dict = edge[2]
        _dict.update({key: "{0:.2f}".format(val) for key, val in _dict.items()})

# %%
graphs['sol'].edges(data = True)

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
G = graphs['sol']
pos = nx.circular_layout(G)


nx.draw_networkx(G,
                 pos = pos,
                 arrowsize = 20,
                 node_size = 1000,
                 node_color = 'lightsteelblue')
plt.savefig(f"thermocycle.png")

# %%
from IPython.display import display, HTML
import pandas as pd

# %%
# students = [ ('jack', 34, 'Sydeny' , 'Australia') ,
#              ('Riti', 30, 'Delhi' , 'India' ) ,
#              ('Vikas', 31, 'Mumbai' , 'India' ) ,
#              ('Neelu', 32, 'Bangalore' , 'India' ) ,
#              ('John', 16, 'New York' , 'US') ,
#              ('Mike', 17, 'las vegas' , 'US')  ]

free_energies = []
indices = []
for edge_sol, edge_vac in zip(graphs['sol'].edges(data = True), graphs['sol'].edges(data = True)):
    a,b, sol_dg, sol_ddg = edge_sol[0], edge_sol[1], float(edge_sol[2]['dg']), float(edge_sol[2]['ddg'])
    vac_dg, vac_ddg = float(graphs['vac'].edges[a, b]['dg']), float(graphs['vac'].edges[a, b]['ddg'])
    dg = sol_dg - vac_dg
    ddg = sol_ddg + vac_ddg
    indices.append((a,b)) 
    free_energies.append((sol_dg, sol_ddg, vac_dg, vac_ddg, dg, ddg))

dg_dict = {index : entry for index, entry in zip(indices, free_energies)}

fb_indices = []
fb_free_energies = []
for peptide_transform in combinations(residues, 2):
    forward, backward = dg_dict[peptide_transform], dg_dict[peptide_transform[::-1]]
    tup = (forward[0] + backward[0], forward[2] + backward[2], forward[4] + backward[4])
    fb_indices.append(peptide_transform)
    fb_free_energies.append(tup)


df_sol = pd.DataFrame(free_energies, columns = ['solvent dG', 'solvent ddG', 'vacuum dG', 'vacuum ddG', 'solvation dG', 'solvation ddG'], index = indices)
fb = pd.DataFrame(fb_free_energies, columns = ['solvent discrepancy', 'vacuum discrepancy', 'solvation energy discrepancy'], index = fb_indices)

# %%
display(df_sol)

# %%
display(fb)

# %%
dg_dict

# %%
tricycles = combinations(residues, 3)
tricycle_list = []
for triplet in tricycles:
    loop = [(i, j) for i, j in [triplet[:2], triplet[1:3], [triplet[2], triplet[0]]]]
    rev_loop = [i[::-1] for i in loop]
    dg = 0
    rev_dg = 0
    for edge in loop:
        dg += dg_dict[edge][4]
    for edge in rev_loop:
        rev_dg += dg_dict[edge][4]
    
    forward_graph = nx.DiGraph(title = dg)
    for edge in loop:
        forward_graph.add_edge(edge[0], edge[1])
    
    reverse_graph = nx.DiGraph(title = rev_dg)
    for edge in rev_loop:
        reverse_graph.add_edge(edge[0], edge[1])
    tricycle_list.append((forward_graph, reverse_graph))

# %%
for tup in tricycle_list:
    fwd_graph, rev_graph = tup
    fwd_pos = nx.circular_layout(fwd_graph)
    rev_pos = nx.circular_layout(rev_graph)


    nx.draw_networkx(fwd_graph,
                     pos = fwd_pos,
                     arrowsize = 20,
                     node_size = 1000,
                     node_color = 'lightsteelblue',
                     label = fwd_graph.graph['title'])
    plt.savefig(f"{tup[0]}.png")
    nx.draw_networkx(rev_graph,
                 pos = rev_pos,
                 arrowsize = 20,
                 node_size = 1000,
                 node_color = 'lightsteelblue',
                 label = rev_graph.graph['title'])
    plt.savefig(f"{tup[1]}.png")

# %%
from perses.analysis import utils

# %% [markdown]
# ## we are going to look at a timeseries...

# %%
_returnable = {}
for peptide_transform in combinations(residues, 2):
    try:
        reporter = MultiStateReporter(f"{peptide_transform[0]}_{peptide_transform[1]}.sol.default_map.nc")
        ncfile = utils.open_netcdf(f"{peptide_transform[0]}_{peptide_transform[1]}.sol.default_map.nc")
        n_iterations = ncfile.variables['last_iteration'][0]
        dg, ddg = list(), list()
        for step in range(1, n_iterations, 30):
            analyzer = MultiStateSamplerAnalyzer(reporter,max_n_iterations = step)
            f_ij, df_ij = analyzer.get_free_energy()
            dg.append(f_ij[0,-1])
            ddg.append(df_ij[0,-1])
        
        _returnable[peptide_transform] = (dg, ddg)
        
    except Exception as e:
        print(e)

import pickle
with open(f"returnable_plotter.pkl", 'wb') as f:
    pickle.dump(_returnable, f)
# Out:
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistatereporter.py:116: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# Could not locate checkpoint subfile. This is okay for analysis if the solvent trajectory is not needed, but not for production simulation!
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:
UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 2
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.0719234943389893
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 14.961942672729492
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.903  -0.798  -0.850  -1.993  -3.435   0.273   3.367   5.731   7.548   8.966
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.903   0.000   0.105   0.053  -1.090  -2.532   1.176   4.270   6.634   8.451   9.870
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.798  -0.105   0.000  -0.052  -1.195  -2.637   1.071   4.165   6.529   8.346   9.765
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.850  -0.053   0.052   0.000  -1.143  -2.585   1.123   4.217   6.581   8.398   9.817
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.993   1.090   1.195   1.143   0.000  -1.442   2.266   5.360   7.724   9.541  10.960
# DEBUG:openmmtools.multistate.multistateanalyzer:   3.435   2.532   2.637   2.585   1.442   0.000   3.708   6.802   9.166  10.983  12.402
# DEBUG:openmmtools.multistate.multistateanalyzer:  -0.273  -1.176  -1.071  -1.123  -2.266  -3.708   0.000   3.094   5.458   7.275   8.694
# DEBUG:openmmtools.multistate.multistateanalyzer:  -3.367  -4.270  -4.165  -4.217  -5.360  -6.802  -3.094   0.000   2.364   4.181   5.600
# DEBUG:openmmtools.multistate.multistateanalyzer:  -5.731  -6.634  -6.529  -6.581  -7.724  -9.166  -5.458  -2.364   0.000   1.817   3.236
# DEBUG:openmmtools.multistate.multistateanalyzer:  -7.548  -8.451  -8.346  -8.398  -9.541 -10.983  -7.275  -4.181  -1.817   0.000   1.418
# DEBUG:openmmtools.multistate.multistateanalyzer:  -8.966  -9.870  -9.765  -9.817 -10.960 -12.402  -8.694  -5.600  -3.236  -1.418   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.063   0.192   0.326   0.365   0.382   0.384   0.410   0.457   0.501   0.541
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.063   0.000   0.145   0.298   0.339   0.358   0.360   0.388   0.437   0.483   0.525
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.192   0.145   0.000   0.191   0.244   0.267   0.271   0.307   0.367   0.421   0.468
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.326   0.298   0.191   0.000   0.070   0.109   0.124   0.193   0.280   0.347   0.403
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.365   0.339   0.244   0.070   0.000   0.046   0.089   0.178   0.270   0.340   0.397
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.382   0.358   0.267   0.109   0.046   0.000   0.088   0.181   0.273   0.342   0.399
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.384   0.360   0.271   0.124   0.089   0.088   0.000   0.105   0.214   0.294   0.358
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.410   0.388   0.307   0.193   0.178   0.181   0.105   0.000   0.120   0.215   0.293
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.457   0.437   0.367   0.280   0.270   0.273   0.214   0.120   0.000   0.107   0.205
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.501   0.483   0.421   0.347   0.340   0.342   0.294   0.215   0.107   0.000   0.111
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.541   0.525   0.468   0.403   0.397   0.399   0.358   0.293   0.205   0.111   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 2
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.1408309936523438
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 28.493608474731445
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.998  -0.981  -0.894  -2.040  -3.481   0.345   3.605   6.151   8.113   9.592
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.998   0.000   0.017   0.104  -1.041  -2.483   1.343   4.603   7.149   9.111  10.590
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.981  -0.017   0.000   0.086  -1.059  -2.500   1.326   4.586   7.132   9.094  10.573
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.894  -0.104  -0.086   0.000  -1.145  -2.586   1.239   4.500   7.045   9.008  10.487
# DEBUG:openmmtools.multistate.multistateanalyzer:   2.040   1.041   1.059   1.145   0.000  -1.441   2.384   5.645   8.190  10.153  11.632
# DEBUG:openmmtools.multistate.multistateanalyzer:   3.481   2.483   2.500   2.586   1.441   0.000   3.825   7.086   9.632  11.594  13.073
# DEBUG:openmmtools.multistate.multistateanalyzer:  -0.345  -1.343  -1.326  -1.239  -2.384  -3.825   0.000   3.260   5.806   7.768   9.248
# DEBUG:openmmtools.multistate.multistateanalyzer:  -3.605  -4.603  -4.586  -4.500  -5.645  -7.086  -3.260   0.000   2.546   4.508   5.987
# DEBUG:openmmtools.multistate.multistateanalyzer:  -6.151  -7.149  -7.132  -7.045  -8.190  -9.632  -5.806  -2.546   0.000   1.962   3.441
# DEBUG:openmmtools.multistate.multistateanalyzer:  -8.113  -9.111  -9.094  -9.008 -10.153 -11.594  -7.768  -4.508  -1.962   0.000   1.479
# DEBUG:openmmtools.multistate.multistateanalyzer:  -9.592 -10.590 -10.573 -10.487 -11.632 -13.073  -9.248  -5.987  -3.441  -1.479   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.041   0.128   0.240   0.271   0.282   0.282   0.299   0.333   0.370   0.404
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.041   0.000   0.094   0.221   0.253   0.265   0.266   0.283   0.319   0.358   0.393
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.128   0.094   0.000   0.154   0.193   0.207   0.208   0.230   0.273   0.318   0.356
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.240   0.221   0.154   0.000   0.053   0.077   0.086   0.133   0.199   0.257   0.303
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.271   0.253   0.193   0.053   0.000   0.030   0.059   0.123   0.193   0.253   0.300
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.282   0.265   0.207   0.077   0.030   0.000   0.057   0.124   0.195   0.254   0.301
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.282   0.266   0.208   0.086   0.059   0.057   0.000   0.075   0.156   0.224   0.276
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.299   0.283   0.230   0.133   0.123   0.124   0.075   0.000   0.091   0.170   0.232
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.333   0.319   0.273   0.199   0.193   0.195   0.156   0.091   0.000   0.090   0.166
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.370   0.358   0.318   0.257   0.253   0.254   0.224   0.170   0.090   0.000   0.090
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.404   0.393   0.356   0.303   0.300   0.301   0.276   0.232   0.166   0.090   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 2
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.121224880218506
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 42.899742126464844
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.271   0.259   0.224   0.185   0.180   0.181   0.163   0.130   0.074   0.000   0.075
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.302   0.291   0.260   0.227   0.223   0.224   0.209   0.183   0.140   0.075   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 2
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.2066807746887207
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 68.4285659790039
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.905  -0.671  -0.683  -1.891  -3.367   0.557   4.028   6.886   9.069  10.516
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.905   0.000   0.234   0.222  -0.987  -2.463   1.462   4.933   7.791   9.973  11.421
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.671  -0.234   0.000  -0.012  -1.221  -2.697   1.228   4.699   7.557   9.739  11.187
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.683  -0.222   0.012   0.000  -1.209  -2.685   1.240   4.711   7.569   9.751  11.199
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.891   0.987   1.221   1.209   0.000  -1.476   2.449   5.920   8.778  10.960  12.407
# DEBUG:openmmtools.multistate.multistateanalyzer:   3.367   2.463   2.697   2.685   1.476   0.000   3.925   7.396  10.253  12.436  13.883
# DEBUG:openmmtools.multistate.multistateanalyzer:  -0.557  -1.462  -1.228  -1.240  -2.449  -3.925   0.000   3.471   6.329   8.511   9.959
# DEBUG:openmmtools.multistate.multistateanalyzer:  -4.028  -4.933  -4.699  -4.711  -5.920  -7.396  -3.471   0.000   2.858   5.040   6.488
# DEBUG:openmmtools.multistate.multistateanalyzer:  -6.886  -7.791  -7.557  -7.569  -8.778 -10.253  -6.329  -2.858   0.000   2.183   3.630
# DEBUG:openmmtools.multistate.multistateanalyzer:  -9.069  -9.973  -9.739  -9.751 -10.960 -12.436  -8.511  -5.040  -2.183   0.000   1.447
# DEBUG:openmmtools.multistate.multistateanalyzer: -10.516 -11.421 -11.187 -11.199 -12.407 -13.883  -9.959  -6.488  -3.630  -1.447   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.028   0.096   0.171   0.188   0.194   0.194   0.202   0.221   0.248   0.275
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.028   0.000   0.074   0.157   0.175   0.181   0.182   0.190   0.210   0.238   0.267
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.096   0.074   0.000   0.100   0.123   0.132   0.133   0.144   0.170   0.203   0.236
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.171   0.157   0.100   0.000   0.033   0.048   0.053   0.079   0.120   0.164   0.204
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.188   0.175   0.123   0.033   0.000   0.019   0.034   0.069   0.115   0.161   0.201
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.194   0.181   0.132   0.048   0.019   0.000   0.032   0.070   0.116   0.161   0.201
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.194   0.182   0.133   0.053   0.034   0.032   0.000   0.043   0.095   0.146   0.189
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.202   0.190   0.144   0.079   0.069   0.070   0.043   0.000   0.057   0.116   0.166
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.221   0.210   0.170   0.120   0.115   0.116   0.095   0.057   0.000   0.067   0.128
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.248   0.238   0.203   0.164   0.161   0.161   0.146   0.116   0.067   0.000   0.071
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.275   0.267   0.236   0.204   0.201   0.201   0.189   0.166   0.128   0.071   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 2
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.269428014755249
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 79.75578308105469
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.888  -0.665  -0.615  -1.760  -3.184   0.656   4.077   6.958   9.228  10.789
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.888   0.000   0.222   0.273  -0.873  -2.296   1.543   4.964   7.845  10.116  11.676
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.665  -0.222   0.000   0.051  -1.095  -2.518   1.321   4.742   7.623   9.893  11.454
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.615  -0.273  -0.051   0.000  -1.146  -2.569   1.270   4.691   7.572   9.843  11.403
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.760   0.873   1.095   1.146   0.000  -1.423   2.416   5.837   8.718  10.989  12.549
# DEBUG:openmmtools.multistate.multistateanalyzer:   3.184   2.296   2.518   2.569   1.423   0.000   3.839   7.260  10.141  12.412  13.972
# DEBUG:openmmtools.multistate.multistateanalyzer:  -0.656  -1.543  -1.321  -1.270  -2.416  -3.839   0.000   3.421   6.302   8.573  10.133
# DEBUG:openmmtools.multistate.multistateanalyzer:  -4.077  -4.964  -4.742  -4.691  -5.837  -7.260  -3.421   0.000   2.881   5.152   6.712
# DEBUG:openmmtools.multistate.multistateanalyzer:  -6.958  -7.845  -7.623  -7.572  -8.718 -10.141  -6.302  -2.881   0.000   2.271   3.831
# DEBUG:openmmtools.multistate.multistateanalyzer:  -9.228 -10.116  -9.893  -9.843 -10.989 -12.412  -8.573  -5.152  -2.271   0.000   1.561
# DEBUG:openmmtools.multistate.multistateanalyzer: -10.789 -11.676 -11.454 -11.403 -12.549 -13.972 -10.133  -6.712  -3.831  -1.561   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.026   0.088   0.155   0.171   0.176   0.177   0.184   0.199   0.222   0.248
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.026   0.000   0.067   0.141   0.158   0.164   0.166   0.172   0.188   0.212   0.240
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.088   0.067   0.000   0.090   0.112   0.120   0.122   0.132   0.152   0.181   0.212
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.155   0.141   0.090   0.000   0.030   0.044   0.050   0.071   0.104   0.143   0.181
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.171   0.158   0.112   0.030   0.000   0.017   0.032   0.062   0.099   0.139   0.178
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.176   0.164   0.120   0.044   0.017   0.000   0.029   0.061   0.099   0.140   0.178
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.177   0.166   0.122   0.050   0.032   0.029   0.000   0.036   0.079   0.125   0.167
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.184   0.172   0.132   0.071   0.062   0.061   0.036   0.000   0.047   0.100   0.148
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.199   0.188   0.152   0.104   0.099   0.099   0.079   0.047   0.000   0.059   0.116
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.222   0.212   0.181   0.143   0.139   0.140   0.125   0.100   0.059   0.000   0.067
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.248   0.240   0.212   0.181   0.178   0.178   0.167   0.148   0.116   0.067   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 1
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.3179845809936523
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 91.4587631225586
# DEBUG:openmmtools.multistate.multistateanalyzer:Assemb
UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 1
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 2.3446714878082275
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 103.21275329589844
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.900  -0.640  -0.508  -1.659  -3.108   0.854   4.413   7.403   9.733  11.307
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.900   0.000   0.260   0.391  -0.759  -2.208   1.753   5.313   8.302  10.632  12.206
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.640  -0.260   0.000   0.131  -1.019  -2.469   1.493   5.053   8.042  10.372  11.946
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.508  -0.391  -0.131   0.000  -1.150  -2.600   1.362   4.921   7.911  10.241  11.815
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.659   0.759   1.019   1.150   0.000  -1.449   2.512   6.072   9.061  11.391  12.965
# DEBUG:openmmtools.multistate.multistateanalyzer:   3.108   2.208   2.469   2.600   1.449   0.000   3.962   7.521  10.511  12.841  14.415
# DEBUG:openmmtools.multistate.multistateanalyzer:  -0.854  -1.753  -1.493  -1.362  -2.512  -3.962   0.000   3.559   6.549   8.879  10.453
# DEBUG:openmmtools.multistate.multistateanalyzer:  -4.413  -5.313  -5.053  -4.921  -6.072  -7.521  -3.559   0.000   2.990   5.320   6.894
# DEBUG:openmmtools.multistate.multistateanalyzer:  -7.403  -8.302  -8.042  -7.911  -9.061 -10.511  -6.549  -2.990   0.000   2.330   3.904
# DEBUG:openmmtools.multistate.multistateanalyzer:  -9.733 -10.632 -10.372 -10.241 -11.391 -12.841  -8.879  -5.320  -2.330   0.000   1.574
# DEBUG:openmmtools.multistate.multistateanalyzer: -11.307 -12.206 -11.946 -11.815 -12.965 -14.415 -10.453  -6.894  -3.904  -1.574   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.022   0.075   0.138   0.154   0.159   0.160   0.165   0.179   0.200   0.223
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.022   0.000   0.058   0.127   0.144   0.149   0.150   0.156   0.170   0.192   0.217
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.075   0.058   0.000   0.083   0.105   0.112   0.113   0.121   0.139   0.165   0.193
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.138   0.127   0.083   0.000   0.029   0.042   0.046   0.063   0.094   0.130   0.164
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.154   0.144   0.105   0.029   0.000   0.016   0.027   0.054   0.089   0.126   0.161
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.159   0.149   0.112   0.042   0.016   0.000   0.025   0.054   0.089   0.127   0.161
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.160   0.150   0.113   0.046   0.027   0.025   0.000   0.032   0.073   0.115   0.152
# DEBUG:openmmtools.multistate.multistateanalyzer:   0
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.046   0.044   0.036   0.024   0.023   0.023   0.020   0.015   0.009   0.000   0.015
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.051   0.049   0.042   0.033   0.032   0.032   0.029   0.026   0.022   0.015   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 1
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 4.433552265167236
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 1928.92724609375
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.820  -0.374  -0.096  -1.267  -2.731   1.299   4.984   8.282  11.242  13.624
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.820   0.000   0.446   0.724  -0.447  -1.911   2.119   5.804   9.102  12.062  14.444
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.374  -0.446   0.000   0.278  -0.893  -2.357   1.673   5.358   8.656  11.616  13.998
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.096  -0.724  -0.278   0.000  -1.171  -2.635   1.394   5.080   8.378  11.338  13.720
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.267   0.447   0.893   1.171   0.000  -1.463   2.566   6.251   9.549  12.509  14.891
# DEBUG:openmmtools.multistate.multistateanalyzer:   2.731   1.911   2.357   2.635   1.463   0.000   4.029   7.715  11.013  13.973  16.355
# DEBUG:openmmtools.multistate.multistateanalyzer:  -1.299  -2.119  -1.673  -1.394  -2.566  -4.029   0.000   3.685   6.983   9.943  12.325
# DEBUG:openmmtools.multistate.multistateanalyzer:  -4.984  -5.804  -5.358  -5.080  -6.251  -7.715  -3.685   0.000   3.298   6.258   8.640
# DEBUG:openmmtools.multistate.multistateanalyzer:  -8.282  -9.102  -8.656  -8.378  -9.549 -11.013  -6.983  -3.298   0.000   2.960   5.342
# DEBUG:openmmtools.multistate.multistateanalyzer: -11.242 -12.062 -11.616 -11.338 -12.509 -13.973  -9.943  -6.258  -2.960   0.000   2.382
# DEBUG:openmmtools.multistate.multistateanalyzer: -13.624 -14.444 -13.998 -13.720 -14.891 -16.355 -12.325  -8.640  -5.342  -2.382   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.005   0.018   0.035   0.039   0.040   0.040   0.041   0.043   0.046   0.050
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.005   0.000   0.014   0.033   0.037   0.038   0.038   0.039   0.041   0.044   0.049
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.018   0.014   0.000   0.023   0.028   0.029   0.029   0.030   0.033   0.036   0.042
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.035   0.033   0.023   0.000   0.007   0.010   0.011   0.014   0.019   0.024   0.033
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.039   0.037   0.028   0.007   0.000   0.004   0.006   0.011   0.017   0.023   0.032
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.040   0.038   0.029   0.010   0.004   0.000   0.006   0.011   0.017   0.023   0.032
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.040   0.038   0.029   0.011   0.006   0.006   0.000   0.006   0.013   0.020   0.029
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.041   0.039   0.030   0.014   0.011   0.011   0.006   0.000   0.007   0.015   0.026
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.043   0.041   0.033   0.019   0.017   0.017   0.013   0.007   0.000   0.009   0.022
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.046   0.044   0.036   0.024   0.023   0.023   0.020   0.015   0.009   0.000   0.015
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.050   0.049   0.042   0.033   0.032   0.032   0.029   0.026   0.022   0.015   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!
# DEBUG:openmmtools.multistate.multistateanalyzer:Equilibration data:
# DEBUG:openmmtools.multistate.multistateanalyzer: number of iterations discarded to equilibration : 1
# DEBUG:openmmtools.multistate.multistateanalyzer: statistical inefficiency of production region   : 4.4000678062438965
# DEBUG:openmmtools.multistate.multistateanalyzer: effective number of uncorrelated samples        : 1950.4244384765625
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling uncorrelated energies...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing free energy differences...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Computing covariance matrix...
# DEBUG:openmmtools.multistate.multistateanalyzer:Deltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000  -0.817  -0.385  -0.136  -1.310  -2.772   1.252   4.936   8.240  11.217  13.602
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.817   0.000   0.433   0.681  -0.493  -1.954   2.070   5.753   9.058  12.034  14.419
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.385  -0.433   0.000   0.249  -0.925  -2.387   1.637   5.321   8.625  11.602  13.986
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.136  -0.681  -0.249   0.000  -1.174  -2.636   1.388   5.072   8.377  11.353  13.738
# DEBUG:openmmtools.multistate.multistateanalyzer:   1.310   0.493   0.925   1.174   0.000  -1.462   2.562   6.246   9.551  12.527  14.912
# DEBUG:openmmtools.multistate.multistateanalyzer:   2.772   1.954   2.387   2.636   1.462   0.000   4.024   7.708  11.012  13.989  16.374
# DEBUG:openmmtools.multistate.multistateanalyzer:  -1.252  -2.070  -1.637  -1.388  -2.562  -4.024   0.000   3.684   6.988   9.965  12.350
# DEBUG:openmmtools.multistate.multistateanalyzer:  -4.936  -5.753  -5.321  -5.072  -6.246  -7.708  -3.684   0.000   3.305   6.281   8.666
# DEBUG:openmmtools.multistate.multistateanalyzer:  -8.240  -9.058  -8.625  -8.377  -9.551 -11.012  -6.988  -3.305   0.000   2.977   5.361
# DEBUG:openmmtools.multistate.multistateanalyzer: -11.217 -12.034 -11.602 -11.353 -12.527 -13.989  -9.965  -6.281  -2.977   0.000   2.385
# DEBUG:openmmtools.multistate.multistateanalyzer: -13.602 -14.419 -13.986 -13.738 -14.912 -16.374 -12.350  -8.666  -5.361  -2.385   0.000
# DEBUG:openmmtools.multistate.multistateanalyzer:dDeltaf_ij:
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.000   0.005   0.018   0.035   0.039   0.040   0.040   0.041   0.042   0.045   0.050
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.005   0.000   0.014   0.033   0.036   0.038   0.038   0.039   0.040   0.043   0.048
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.018   0.014   0.000   0.022   0.027   0.029   0.029   0.030   0.032   0.036   0.042
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.035   0.033   0.022   0.000   0.007   0.009   0.010   0.014   0.018   0.024   0.032
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.039   0.036   0.027   0.007   0.000   0.003   0.006   0.011   0.017   0.023   0.031
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.040   0.038   0.029   0.009   0.003   0.000   0.005   0.011   0.017   0.023   0.032
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.040   0.038   0.029   0.010   0.006   0.005   0.000   0.006   0.013   0.019   0.029
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.041   0.039   0.030   0.014   0.011   0.011   0.006   0.000   0.007   0.015   0.026
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.042   0.040   0.032   0.018   0.017   0.017   0.013   0.007   0.000   0.009   0.022
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.045   0.043   0.036   0.024   0.023   0.023   0.019   0.015   0.009   0.000   0.015
# DEBUG:openmmtools.multistate.multistateanalyzer:   0.050   0.048   0.042   0.032   0.031   0.032   0.029   0.026   0.022   0.015   0.000
# /home/dominic/anaconda3/envs/openmm/lib/python3.6/site-packages/openmmtools-0.18.3-py3.6-linux-x86_64.egg/openmmtools/multistate/multistateanalyzer.py:1175: UserWarning: Warning: The openmmtools.multistate API is experimental and may change in future releases
#   warnings.warn('Warning: The openmmtools.multistate API is experimental and may change in future releases')
# DEBUG:openmmtools.multistate.multistateanalyzer:Checking if we need to unbias the restraint...
# DEBUG:openmmtools.multistate.multistateanalyzer:Trying to get radially symmetric restraint data...
# DEBUG:openmmtools.multistate.multistateanalyzer:Retrieving end thermodynamic states...
# DEBUG:openmmtools.multistate.multistateanalyzer:Isolating restraint force...
# DEBUG:openmmtools.multistate.multistateanalyzer:No force of type <class 'openmmtools.forces.RadiallySymmetricRestraintForce'> could be found. The restraint will not be unbiased.
# DEBUG:openmmtools.multistate.multistateanalyzer:Reading energies...
# DEBUG:openmmtools.multistate.multistatereporter:read_replica_thermodynamic_states: iteration = [    0     1     2 ...  9998  9999 10000]
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Assembling effective timeseries...
# DEBUG:openmmtools.multistate.multistateanalyzer:Done.
# DEBUG:openmmtools.multistate.multistateanalyzer:Could not find t0: None of the requested keys could be found on disk!

# %%
plt.plot(dg)
plt.fill_between(range(len(dg)),np.asarray(dg)-np.asarray(ddg),np.asarray(dg)+np.asarray(ddg),alpha=0.2)
plt.title(f"CYS -> SER (solvent)")
plt.xlabel()
